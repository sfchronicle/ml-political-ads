# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import json
import spacy
from spacy.matcher import PhraseMatcher

# %%
def get_text_from_csv(fn): # get ad's text from csv file, return a dataframe with text, ad_id,ad_url, and report_url
    df = pd.read_csv(fn)
    df = df[df['ad_type'] == 'Text'].reset_index(drop = True) # only get text ads
    df_url = df[['ad_id','ad_url']].reset_index(drop = True) # get the urls
    urls = df_url['ad_url'].to_list() # create a list so we could get the report_urls
    report_urls = []
    for url in urls:
        entity_id = url.split('/')[-3]
        creative_id = url.split('/')[-1]
        report_url = 'https://transparencyreport.google.com/transparencyreport/api/v3/politicalads/creatives/details?entity_id={}&creative_id={}&hl=en'.format(entity_id,creative_id)
        report_urls.append(report_url)
    df_report = pd.DataFrame(report_urls).rename(columns = {0:'report_url'})
    ad_text = [] # get texts from reports
    for report_url in report_urls:
        response = requests.get(report_url)
        text = response.text.split('"]')[0].split('[')[-1]
        ad_text.append(text)  
    df_text = pd.DataFrame(ad_text).rename(columns = {0:'text'})
    df_new = df[df['ad_type']=='Text'][['ad_id','ad_url']].reset_index(drop = True) 
    df = pd.concat([df_new,df_report,df_text],axis=1)
    return df

# %%
df_text = get_text_from_csv('GoogleAds/CT.csv')
df_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ad_id       54 non-null     object
#  1   ad_url      54 non-null     object
#  2   report_url  54 non-null     object
#  3   text        54 non-null     object
# dtypes: object(4)
# memory usage: 1.8+ KB

# %%
df_text.head()
# Out:
#                   ad_id                                             ad_url  \
# 0  CR442831434822975488  https://transparencyreport.google.com/politica...
# 1  CR217284766326587392  https://transparencyreport.google.com/politica...
# 2  CR144710676701511680  https://transparencyreport.google.com/politica...
# 3  CR448694580578091008  https://transparencyreport.google.com/politica...
# 4  CR165583530565304320  https://transparencyreport.google.com/politica...
#
#                                           report_url  \
# 0  https://transparencyreport.google.com/transpar...
# 1  https://transparencyreport.google.com/transpar...
# 2  https://transparencyreport.google.com/transpar...
# 3  https://transparencyreport.google.com/transpar...
# 4  https://transparencyreport.google.com/transpar...
#
#                                                 text
# 0  "Our Democrat opponent outraised us last quart...
# 1  "Our Democrat opponent outraised us last quart...
# 2  "It's time to focus on the hard-working famili...
# 3  "Our Democrat opponent outraised us last quart...
# 4  "Georgia will decide the Senate Majority in 20...

# %%
# check the dataset 
if df_text['text'].isnull().sum():
    print (df_text['text'].isnull().sum())
    df_text = df_text[df_text['text'].notnull()]
    df_text.reset_index(drop=True,inplace=True)

# %%
# function that filter the urls and symbols in the text 
def filter_text(x):
    url = 'http[s]?://\S+'
    x = re.sub(url,'',x)
    x = re.sub("[^\w\s]",' ',x) # filter symbols
    x = re.sub("\s+",' ',x)
    
    ls=[w.lower() for w in x.split()] 
    
    return ' '.join(ls)

# %%
df_text['text'] = df_text['text'].astype(str).apply(lambda x: filter_text(x))
df_text.head()
# Out:
#                   ad_id                                             ad_url  \
# 0  CR442831434822975488  https://transparencyreport.google.com/politica...
# 1  CR217284766326587392  https://transparencyreport.google.com/politica...
# 2  CR144710676701511680  https://transparencyreport.google.com/politica...
# 3  CR448694580578091008  https://transparencyreport.google.com/politica...
# 4  CR165583530565304320  https://transparencyreport.google.com/politica...
#
#                                           report_url  \
# 0  https://transparencyreport.google.com/transpar...
# 1  https://transparencyreport.google.com/transpar...
# 2  https://transparencyreport.google.com/transpar...
# 3  https://transparencyreport.google.com/transpar...
# 4  https://transparencyreport.google.com/transpar...
#
#                                                 text
# 0  our democrat opponent outraised us last quarte...
# 1  our democrat opponent outraised us last quarte...
# 2  it s time to focus on the hard working familie...
# 3  our democrat opponent outraised us last quarte...
# 4  georgia will decide the senate majority in 202...

# %%
# remove duplicated rows
df_text.drop_duplicates(subset = 'text',keep = 'first',inplace = True)
df_text.reset_index(inplace = True,drop = True)
df_text.head()
# Out:
#                   ad_id                                             ad_url  \
# 0  CR442831434822975488  https://transparencyreport.google.com/politica...
# 1  CR217284766326587392  https://transparencyreport.google.com/politica...
# 2  CR144710676701511680  https://transparencyreport.google.com/politica...
# 3  CR165583530565304320  https://transparencyreport.google.com/politica...
# 4  CR402139334112706560  https://transparencyreport.google.com/politica...
#
#                                           report_url  \
# 0  https://transparencyreport.google.com/transpar...
# 1  https://transparencyreport.google.com/transpar...
# 2  https://transparencyreport.google.com/transpar...
# 3  https://transparencyreport.google.com/transpar...
# 4  https://transparencyreport.google.com/transpar...
#
#                                                 text
# 0  our democrat opponent outraised us last quarte...
# 1  our democrat opponent outraised us last quarte...
# 2  it s time to focus on the hard working familie...
# 3  georgia will decide the senate majority in 202...
# 4  help herschel walker reach his critical end of...

# %%
df_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ad_id       27 non-null     object
#  1   ad_url      27 non-null     object
#  2   report_url  27 non-null     object
#  3   text        27 non-null     object
# dtypes: object(4)
# memory usage: 992.0+ bytes

# %%
df_text.to_csv('ct_ad.csv')

# %%
# import the Lexicon
with open ('lexicon.json') as f1:
    dic1 = json.load(f1)
# check the keys
dic1.keys()
# Out:
# dict_keys(['covid', 'economic', 'education', 'environment', 'foreign policy', 'governance', 'health', 'immigration', 'military', 'safety', 'social and cultural', 'social programs', 'donation'])

# %%
# import en_core_web
#This only happens to Ying that she couldn't import 'en_core_web_sm' in Jupyter Notebook, so she imports it with the full path
nlp = spacy.load("/usr/local/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages/en_core_web_lg/en_core_web_lg-3.2.0/")

# %%
# the function that find the lexicon words in the text
def find_words(x,lexicon):
    topics= lexicon.keys()  
    doc = nlp(x) # nlp() is spaCy 2.2 English language model 
    words= []
    for t in topics:
        matcher = PhraseMatcher(nlp.vocab)
        terms= lexicon[t]
        patterns = [nlp.make_doc(text) for text in terms]
        matcher.add("TerminologyList", patterns) # spaCy2.2 phrase matcher
        matches = matcher(doc)
        for match_id, start,end in matches:
            span = doc[start:end]
            words.append(span.text)
    if words:
        words = list(set(words))
        return ','.join(words)
    else:
        return('no words')

# %%
# tagging the topic in each message
def find_topic(x,lexicon):
    topics= lexicon.keys()    
    if x=='no words':
        return ''    
    if x != 'no words': 
        words = x.split(',')
        labels = []        
        for t in topics:            
            terms = lexicon[t]
            if set(words)&set(terms):
                labels.append(t)                
                #l = sorted(labels)        
        return  ','.join(sorted(labels))
                
        #return ','.join(labels)

# %%
df_text['words'] = df_text['text'].astype(str).apply(lambda x: find_words(x,dic1))
df_text['m_label'] = df_text['words'].apply(lambda x: find_topic(x,dic1))
df_text['m_label'] = df_text['m_label'].apply(lambda x: 'no topic' if x=='' else x)
df_text
# Out:
#                    ad_id                                             ad_url  \
# 0   CR442831434822975488  https://transparencyreport.google.com/politica...
# 1   CR217284766326587392  https://transparencyreport.google.com/politica...
# 2   CR144710676701511680  https://transparencyreport.google.com/politica...
# 3   CR165583530565304320  https://transparencyreport.google.com/politica...
# 4   CR402139334112706560  https://transparencyreport.google.com/politica...
# 5    CR75909561227149312  https://transparencyreport.google.com/politica...
# 6   CR441597782776610816  https://transparencyreport.google.com/politica...
# 7    CR26022519651696640  https://transparencyreport.google.com/politica...
# 8   CR512656470500704256  https://transparencyreport.google.com/politica...
# 9   CR523746144778452992  https://transparencyreport.google.com/politica...
# 10  CR103587429994201088  https://transparencyreport.google.com/politica...
# 11  CR276364687182921728  https://transparencyreport.google.com/politica...
# 12   CR43775234393767936  https://transparencyreport.google.com/politica...
# 13  CR345933674090332160  https://transparencyreport.google.com/politica...
# 14  CR366114660262346752  https://transparencyreport.google.com/politica...
# 15  CR319333739035361280  https://transparencyreport.google.com/politica...
# 16  CR320760905128214528  https://transparencyreport.google.com/politica...
# 17  CR528988616219688960  https://transparencyreport.google.com/politica...
# 18   CR54562405534924800  https://transparencyreport.google.com/politica...
# 19  CR149905594264846336  https://transparencyreport.google.com/politica...
# 20  CR349893565217767424  https://transparencyreport.google.com/politica...
# 21  CR282480308295565312  https://transparencyreport.google.com/politica...
# 22  CR350187134822383616  https://transparencyreport.google.com/politica...
# 23  CR104292354386558976  https://transparencyreport.google.com/politica...
# 24  CR397225891526082560  https://transparencyreport.google.com/politica...
# 25  CR449712728345411584  https://transparencyreport.google.com/politica...
# 26   CR95335182910881792  https://transparencyreport.google.com/politica...
#
#                                            report_url  \
# 0   https://transparencyreport.google.com/transpar...
# 1   https://transparencyreport.google.com/transpar...
# 2   https://transparencyreport.google.com/transpar...
# 3   https://transparencyreport.google.com/transpar...
# 4   https://transparencyreport.google.com/transpar...
# 5   https://transparencyreport.google.com/transpar...
# 6   https://transparencyreport.google.com/transpar...
# 7   https://transparencyreport.google.com/transpar...
# 8   https://transparencyreport.google.com/transpar...
# 9   https://transparencyreport.google.com/transpar...
# 10  https://transparencyreport.google.com/transpar...
# 11  https://transparencyreport.google.com/transpar...
# 12  https://transparencyreport.google.com/transpar...
# 13  https://transparencyreport.google.com/transpar...
# 14  https://transparencyreport.google.com/transpar...
# 15  https://transparencyreport.google.com/transpar...
# 16  https://transparencyreport.google.com/transpar...
# 17  https://transparencyreport.google.com/transpar...
# 18  https://transparencyreport.google.com/transpar...
# 19  https://transparencyreport.google.com/transpar...
# 20  https://transparencyreport.google.com/transpar...
# 21  https://transparencyreport.google.com/transpar...
# 22  https://transparencyreport.google.com/transpar...
# 23  https://transparencyreport.google.com/transpar...
# 24  https://transparencyreport.google.com/transpar...
# 25  https://transparencyreport.google.com/transpar...
# 26  https://transparencyreport.google.com/transpar...
#
#                                                  text             words  \
# 0   our democrat opponent outraised us last quarte...          no words
# 1   our democrat opponent outraised us last quarte...          no words
# 2   it s time to focus on the hard working familie...            donate
# 3   georgia will decide the senate majority in 202...          no words
# 4   help herschel walker reach his critical end of...            donate
# 5   we must prioritize lowering barriers between m...           savings
# 6   gov lamont is touting a proposal that would th...          no words
# 7   the january 6 insurrection kicked off a concer...          no words
# 8   leora is running for senate to retire dick blu...          no words
# 9   the january 6 insurrection kicked off a concer...          no words
# 10  support harry arora define a long term sustain...          no words
# 11  take the politics out of the treasury and inve...          no words
# 12  georgia will decide the senate majority in 202...            donate
# 13  bob stefanowski has a plan to lower taxes and ...             taxes
# 14  gov lamont is touting a proposal that would th...          vaccines
# 15  if we want action on the problems facing ameri...        filibuster
# 16  leora levy is the best conservative to take on...          no words
# 17  states are passing laws to silence voters fede...          no words
# 18  dick blumenthal and joe biden s policies are w...          no words
# 19   don t be left behind support a true conservative          no words
# 20  leora levy has lived the american dream she es...          no words
# 21  leora is the conservative who can win in novem...          no words
# 22  ned lamont has led the way during covid to mak...  covid,taxes,jobs
# 23  the connecticut dream is worth fighting for vo...          no words
# 24  the filibuster is used to block protections fo...        filibuster
# 25  leora is a jewish hispanic woman who will say ...            border
# 26  leora knows what happens when we allow mobs to...          no words
#
#             m_label
# 0          no topic
# 1          no topic
# 2          donation
# 3          no topic
# 4          donation
# 5          economic
# 6          no topic
# 7          no topic
# 8          no topic
# 9          no topic
# 10         no topic
# 11         no topic
# 12         donation
# 13         economic
# 14  social programs
# 15       governance
# 16         no topic
# 17         no topic
# 18         no topic
# 19         no topic
# 20         no topic
# 21         no topic
# 22   covid,economic
# 23         no topic
# 24       governance
# 25      immigration
# 26         no topic

# %%
def count_tag(df_text):
    df_tag = df_text['m_label'].value_counts().rename_axis('topics').reset_index(name='counts')
    df_tag = df_tag.assign(single_topic=df_tag['topics'].str.split(',')).explode('single_topic').reset_index(drop = True)
    df_tag = df_tag.groupby('single_topic').sum().reset_index().sort_values(by = 'counts', ascending = False)
    return df_tag

# %%
count_tag(df_text)
# Out:
#       single_topic  counts
# 5         no topic      17
# 1         donation       3
# 2         economic       3
# 3       governance       2
# 0            covid       1
# 4      immigration       1
# 6  social programs       1

# %%
def count_word(df_text):
    df_words = df_text['words'].value_counts().rename_axis('words').reset_index(name='counts')
    df_words = df_words.assign(single_word=df_words['words'].str.split(',')).explode('single_word').reset_index(drop = True)
    df_words = df_words.groupby('single_word').sum().reset_index().sort_values(by = 'counts', ascending = False)
    df_words.reset_index(drop = True, inplace = True)
    return df_words

# %%
count_word(df_text)
# Out:
#   single_word  counts
# 0    no words      17
# 1      donate       3
# 2  filibuster       2
# 3       taxes       2
# 4      border       1
# 5       covid       1
# 6        jobs       1
# 7     savings       1
# 8    vaccines       1
