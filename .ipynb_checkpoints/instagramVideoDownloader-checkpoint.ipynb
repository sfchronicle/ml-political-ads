# %%
#from PIL import Image
import facebook
#import pytesseract
import requests
# import html
from bs4 import BeautifulSoup
from moviepy.editor import *
import pandas as pd
import glob
import os
# from googletrans import Translator
import speech_recognition as sr
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence
from datetime import date
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

# %%
df = pd.read_csv('FacebookAds/CT.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                 ad_creative_bodies  \
# 0           0  ["Please join CEA's Red for Ed Day of Action t...
# 1           1  ['Thinking about attending a Connecticut State...
# 2           2  ['Governor Lamont is protecting abortion right...
# 3           3  ['Hey Connecticut, have you heard? Governor La...
# 4           4  ['Cost increases are hitting families in Conne...
#
#                        ad_creative_link_descriptions  \
# 0  ["With only nine days left in the legislative ...
# 1                                                NaN
# 2          ['Gov. Lamont to sign key abortion bill']
# 3                   ['Gov. Lamont suspends gas tax']
# 4                                 ['Sign up now >>']
#
#                              bylines  \
# 0  CONNECTICUT EDUCATION ASSOCIATION
# 1                   odonnell company
# 2                         NED FOR CT
# 3                         NED FOR CT
# 4                         NED FOR CT
#
#                              ad_creative_link_titles  \
# 0  ['Join us in Hartford or from Your School for ...
# 1                                                NaN
# 2                       ['Sign up for more updates']
# 3                       ['Sign up for more updates']
# 4                   ['Gov. Lamont suspends gas tax']
#
#   ad_creative_link_captions  \
# 0               ['cea.org']
# 1                       NaN
# 2         ['nedlamont.com']
# 3         ['nedlamont.com']
# 4         ['nedlamont.com']
#
#                             demographic_distribution  \
# 0  [{'percentage': '0.000954', 'age': '65+', 'gen...
# 1  [{'percentage': '0.000541', 'age': '13-17', 'g...
# 2  [{'percentage': '0.018349', 'age': '18-24', 'g...
# 3                                                NaN
# 4                                                NaN
#
#                                  page_name          page_id                id  \
# 0  Connecticut Education Association (CEA)     124383441363   688988779084177
# 1     Connecticut State Community Colleges  406907476563016   247626834204512
# 2                               Ned Lamont     196395247518  1318295712031128
# 3                               Ned Lamont     196395247518  1072615439989473
# 4                               Ned Lamont     196395247518   667887484316111
#
#    estimated_audience_size.lower_bound  estimated_audience_size.upper_bound  \
# 0                             100001.0                             500000.0
# 1                             500001.0                            1000000.0
# 2                             500001.0                            1000000.0
# 3                             500001.0                            1000000.0
# 4                             500001.0                            1000000.0
#
#    impressions.lower_bound  impressions.upper_bound  spend.lower_bound  \
# 0                    10000                    14999                200
# 1                     2000                     2999                100
# 2                        0                      999                  0
# 3                        0                      999                  0
# 4                        0                      999                  0
#
#    spend.upper_bound
# 0                299
# 1                199
# 2                 99
# 3                 99
# 4                 99

# %%
# df = df[df.id == 356033606584492]
# df

# %%
r = sr.Recognizer()

# %%
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 150,
        # adjust this per requirement
        silence_thresh = sound.dBFS-4,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
# video = VideoFileClip(vidURL)
# audio = video.audio
# audio.write_audiofile('audio.wav')

# %%
files = glob.glob('/audio-chunks/*')

# %%
vidURL = ''
videoCaptions = []
for index, row in df.iterrows():
    # myDict = {'q':str(row['id']),'access_token':nuToken,'active_status':'all','ad_type','political_and_issue_ads'}
    try:
        myDict = {'id':str(row['id'])}
        print(row['id'])
        options = Options()
        options.add_argument('--headless')
        driver = webdriver.Firefox(options=options)
        driver.get(f'https://www.facebook.com/ads/library/?id={row["id"]}')

    #     profile = graph.get_object('ads_archive',ad_active_status='all',ad_delivery_date_max=today,ad_delivery_date_min='2019-06-01',fields='ad_snapshot_url',search_terms="''",ad_type='POLITICAL_AND_ISSUE_ADS',ad_reached_countries=['US'],limit=25)
    #     header = {'access_token': nuToken}
        # url = 'https://www.facebook.com/ads/library/?'
        # response = requests.get(url, params=myDict)
        #print(response.status_code)
        html = driver.page_source
        soup = BeautifulSoup(html)
        # soup = BeautifulSoup(response.text)
        vidURL = soup.find('video')['src']
        driver.close()
        print(vidURL)
        video = VideoFileClip(vidURL)
        audio = video.audio
        audio.write_audiofile('audio.wav')
        text_to_check = get_large_audio_transcription('audio.wav')
        print(text_to_check)
        videoCaptions.append(text_to_check)
    except:
        text_to_check = 'No Video'
        print(text_to_check)
        videoCaptions.append(text_to_check)
    for f in files:
        os.remove(f)
    os.remove('audio.wav')
    #break
# Out:
# 688988779084177
# No Video
# 247626834204512
# No Video
# 1318295712031128
# No Video
# 1072615439989473
# No Video
# 667887484316111
# No Video
# 543889903963959
# No Video
# 680652063196948
# No Video
# 672181540670736
# No Video
# 379247100880890
# No Video
# 2086806288164112
# No Video
# 514755416851183
# No Video
# 722560848883589
# No Video
# 847272886233140
# No Video
# 1251169975290353
# No Video
# 1040074760265337
# No Video
# 981576472489908
# No Video
# 387255943263605
# No Video
# 1631029237281848
# No Video
# 748463652812276
# No Video
# 980407099272366
# No Video
# 695767441755274
# No Video
# 1032174547726044
# No Video
# 1061663984418099
# No Video
# 979793666011078
# No Video
# 5063831877043488
# No Video
# 749080366102845
# No Video
# 1035484010387118
# No Video
# 387225913274337
# No Video
# 384490843539646
# No Video
# 669465027467608
# No Video
# 994331981449387
# No Video
# 379140180617890
# No Video
# 2110828789097142
# No Video
# 1027625728165114
# No Video
# 524940525685726
# No Video
# 686053639268298
# No Video
# 1036377820326980
# No Video
# 1311991095955562
# No Video
# 1669347430064952
# No Video
# 548211559975086
# No Video
# 581428402991700
# No Video
# 654946748937182
# No Video
# 668680434193711
# No Video
# 707296337054856
# No Video
# 3254161154863067
# No Video
# 337474225142951
# No Video
# 410906994209648
# No Video
# 558594578911534
# No Video
# 586706009022722
# No Video
# 856565919078734
# No Video
# 989948108384356
# No Video
# 1168081547092952
# No Video
# 699570504513835
# No Video
# 359764382785410
# No Video
# 495667409008312
# No Video
# 754216205957340
# No Video
# 1061673534558637
# No Video
# 3180328128903875
# No Video
# 1900521790142184
# No Video
# 453834479829334
# No Video
# 5437852872905552
# No Video
# 946836379322610
# No Video
# 298712289082317
# No Video
# 786018829444602
# No Video
# 1164968634269456
# No Video
# 1430583970705114
# No Video
# 1165636734187335
# No Video
# 1990694911118005
# No Video
# 1647487222297724
# No Video
# 391084076208124
# No Video
# 5431994030157744
# No Video
# 521291009406999
# No Video
# 648713996561281
# No Video
# 719067522564267
# No Video
# 353522483418627
# No Video
# 4460917097341719
# No Video
# 1208608916611953
# No Video
# 2026821617497730
# No Video
# 410485267131597
# No Video
# 753228442720548
# No Video
# 278833854465631
# No Video
# 301701465454560
# No Video
# 402273155009893
# No Video
# 712590033269746
# No Video
# 1012380609704385
# No Video
# 3325813600979796
# No Video
# 1004235530212461
# No Video
# 698718684776234
# No Video
# 1210259523102681
# No Video
# 1155327168559149
# No Video
# 1352780045189860
# No Video
# 315371274056404
# No Video
# 4909577825756222
# No Video
# 2012578052258439
# No Video
# 728613054982675
# No Video
# 356309672981539
# No Video
# 1118719552310853
# No Video
# 1180501566102644
# No Video
# 681785839559948
# No Video
# 7333642176708000
# No Video
# 307907988157258
# No Video
# 1605515356502073
# No Video
# 931763944170964
# No Video
# 555687606170402
# No Video
# 551757239625380
# No Video
# 2111438752343995
# No Video
# 399209458432907
# No Video
# 1014911445801099
# No Video
# 677939943462505
# No Video
# 400677335174540
# No Video
# 380583057272782
# No Video
# 300748978907283
# No Video
# 669755827438967
# No Video
# 575971813859705
# No Video
# 1001466417153207
# No Video
# 1009138729734580
# No Video
# 1418672578580854
# No Video
# 1735944989934139
# No Video
# 558265362537784
# No Video
# 1464019907347429
# No Video
# 516501436720506
# No Video
# 1169521533883971
# No Video
# 1526601294403839
# No Video
# 984979982211977
# No Video
# 409513884509452
# No Video
# 380290787321048
# No Video
# 1064270484188047
# No Video
# 1177324569751306
# No Video
# 1106265496895881
# No Video
# 675530023727940
# No Video
# 492658362557451
# No Video
# 413027153980621
# No Video
# 561603211844244
# No Video
# 491215412737806
# No Video
# 5129310470445450
# No Video
# 404025961561939
# No Video
# 1074903970112081
# No Video
# 360202546126877
# No Video
# 1010140012961883
# No Video
# 506428824505414
# No Video
# 699042714635011
# No Video
# 676296813674629
# No Video
# 5559354770750060
# No Video
# 1123890671518541
# No Video
# 667433524334472
# No Video
# 1140335686757604
# No Video
# 511304500613685
# No Video
# 1096217740927347
# No Video
# 1129932024438190
# No Video
# 750623962609715
# No Video
# 2218882244919489
# No Video
# 3200090400225709
# No Video
# 381387023883250
# No Video
# 654538615637142
# No Video
# 561326565310764
# No Video
# 506622884301079
# No Video
# 321028316640935
# No Video
# 529728195540709
# No Video
# 305012635123809
# No Video
# 302049908780137
# https://video-lax3-2.xx.fbcdn.net/v/t42.1790-2/278623273_302049938780134_1361892407045079355_n.?_nc_cat=106&ccb=1-7&_nc_sid=cf96c8&_nc_ohc=b0I5IZECx14AX_8xWXy&_nc_ht=video-lax3-2.xx&oh=00_AT8yCi1DothWZYem60CCRZYOZCttwhFHVZgTCeUDBF4vug&oe=62A7CD93
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
#
# 3085780885006426
# No Video
# 1747156415459342
# No Video
# 562157291798554
# https://video-lax3-1.xx.fbcdn.net/v/t42.1790-2/278615649_562157318465218_7557791674332932552_n.?_nc_cat=104&ccb=1-7&_nc_sid=cf96c8&_nc_ohc=fFXhmifwsY8AX9ADYGd&_nc_ht=video-lax3-1.xx&oh=00_AT-nKS0lLqbjJO2AQwEm7imlwIS1vK0wzS7aQceIwnt6Ow&oe=62A7D474
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
#
# 519442029861072
# No Video
# 1265093954024789
# No Video
# 515922503396871
# No Video
# 402496978040624
# https://video-lax3-2.xx.fbcdn.net/v/t42.1790-2/10000000_394722122085235_5957776900580538998_n.?_nc_cat=101&ccb=1-7&_nc_sid=cf96c8&_nc_ohc=wKYB0uDyd4UAX_NnbqX&_nc_ht=video-lax3-2.xx&oh=00_AT-H7g_SRNHxLYVJ1aUpvX_XyqIwHwq27gPdvs0LSTcHGQ&oe=62A7D5BF
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
# Error:
# audio-chunks/chunk2.wav : Good morning 7 minutes.
# audio-chunks/chunk3.wav : Brb.
# audio-chunks/chunk4.wav : You are listening again to 94 9 news now.
# Error:
# audio-chunks/chunk6.wav : Talk we are.
# Error:
# audio-chunks/chunk8.wav : Sing out over connecticut rhode island in long island.
# audio-chunks/chunk9.wav : Email me leo p radio gmail.
# audio-chunks/chunk10.wav : Tom.
# audio-chunks/chunk11.wav : Like our page.
# Error:
# Error:
# audio-chunks/chunk14.wav : Voice.
# audio-chunks/chunk15.wav : Freedom.
# audio-chunks/chunk16.wav : And i actually.
# audio-chunks/chunk17.wav : Check.
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk23.wav : Waiting.
# Error:
# audio-chunks/chunk25.wav : Page.
# audio-chunks/chunk26.wav : I guess i'm not going to be able to do it today.
# Error:
# Error:
# audio-chunks/chunk29.wav : Camera.
# audio-chunks/chunk30.wav : Studio when i get there.
# audio-chunks/chunk31.wav : But that week.
# Error:
# Error:
# audio-chunks/chunk34.wav : First time i've ever really.
# audio-chunks/chunk35.wav : I got the.
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk40.wav : Bran.
# audio-chunks/chunk41.wav : New.
# Error:
# Error:
# Error:
# audio-chunks/chunk45.wav : Please say hi to.
# audio-chunks/chunk46.wav : Report.
# audio-chunks/chunk47.wav : Good morning how are you.
# audio-chunks/chunk48.wav : Good morning.
# audio-chunks/chunk49.wav : Thanks for having me.
# audio-chunks/chunk50.wav : I appreciate it.
# Error:
# audio-chunks/chunk52.wav : Start with a.
# Error:
# audio-chunks/chunk54.wav : For a long long time so.
# audio-chunks/chunk55.wav : Initial.
# Error:
# Error:
# audio-chunks/chunk58.wav : Why.
# audio-chunks/chunk59.wav : Why do you want to jump.
# Error:
# Error:
# audio-chunks/chunk62.wav : You know i'm a.
# audio-chunks/chunk63.wav : Stage of my life.
# audio-chunks/chunk64.wav : Where.
# audio-chunks/chunk65.wav : I think i have.
# Error:
# Error:
# audio-chunks/chunk68.wav : Can add value.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk77.wav : Parrot.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk84.wav : I know all the ins and outs.
# audio-chunks/chunk85.wav : Running a business.
# Error:
# audio-chunks/chunk87.wav : Challenges and.
# audio-chunks/chunk88.wav : Activities in the area.
# audio-chunks/chunk89.wav : Have the background.
# Error:
# Error:
# audio-chunks/chunk92.wav : So.
# audio-chunks/chunk93.wav : You know.
# Error:
# audio-chunks/chunk95.wav : It's incumbent upon people at.
# Error:
# Error:
# Error:
# audio-chunks/chunk99.wav : Anime.
# audio-chunks/chunk100.wav : Get in the.
# audio-chunks/chunk101.wav : Yeah exactly.
# audio-chunks/chunk102.wav : You know i mean.
# Error:
# Error:
# audio-chunks/chunk105.wav : I've heard horror stories..
# Error:
# Error:
# Error:
# audio-chunks/chunk109.wav : Eminem.
# audio-chunks/chunk110.wav : So you never held.
# Error:
# Error:
# audio-chunks/chunk113.wav : Before or.
# Error:
# audio-chunks/chunk115.wav : No no i mean.
# audio-chunks/chunk116.wav : I've been involved in.
# audio-chunks/chunk117.wav : Chambers.
# audio-chunks/chunk118.wav : Call mariah.
# audio-chunks/chunk119.wav : Run a business.
# audio-chunks/chunk120.wav : But never.
# Error:
# Error:
# Error:
# audio-chunks/chunk124.wav : So.
# audio-chunks/chunk125.wav : The business.
# audio-chunks/chunk126.wav : So.
# Error:
# audio-chunks/chunk128.wav : We do.
# Error:
# Error:
# audio-chunks/chunk131.wav : So weird.
# Error:
# audio-chunks/chunk133.wav : Weebill.
# audio-chunks/chunk134.wav : Technical.
# Error:
# audio-chunks/chunk136.wav : We we.
# audio-chunks/chunk137.wav : It started.
# Error:
# Error:
# audio-chunks/chunk140.wav : Whitney in the air.
# audio-chunks/chunk141.wav : Or something.
# audio-chunks/chunk142.wav : Dad and they're not.
# audio-chunks/chunk143.wav : Built.
# audio-chunks/chunk144.wav : Cool from now.
# audio-chunks/chunk145.wav : To do.
# Error:
# audio-chunks/chunk147.wav : Maintain.
# audio-chunks/chunk148.wav : Overhaul.
# Error:
# Error:
# audio-chunks/chunk151.wav : So.
# audio-chunks/chunk152.wav : Okay.
# audio-chunks/chunk153.wav : Alright.
# audio-chunks/chunk154.wav : Don't listen before it gets it.
# Error:
# Error:
# audio-chunks/chunk157.wav : Speedway fuel.
# audio-chunks/chunk158.wav : Call in.
# Error:
# audio-chunks/chunk160.wav : Tim mannino.
# No Video
# 1675848346097208
# No Video
# 2839538126339024
# No Video
# 1008890410025585
# No Video
# 674985297111600
# No Video
# 291462259696691
# No Video
# 506402370945476
# No Video
# 1139003136935479
# No Video
# 691327788582812
# No Video
# 368494211871820
# No Video
# 1930411760476390
# No Video
# 317190833772557
# No Video
# 514144690298839
# No Video
# 4989291441189919
# No Video
# 1089283578291233
# No Video
# 522458429452040
# No Video
# 711391293382605
# No Video
# 285297150468395
# No Video
# 5197046000318525
# No Video
# 1025406298410396
# No Video
# 1638913676442608
# No Video
# 741076590390759
# No Video
# 7214166418658192
# No Video
# 3180545348858491
# No Video
# 696065088204725
# No Video
# 1022339338710473
# No Video
# 656035072366472
# No Video
# 562260391732933
# No Video
# 520412176128279
# No Video
# 3040580829492726
# No Video
# 673795330492023
# No Video
# 383933550266492
# No Video
# 515772360047549
# https://video-lax3-1.xx.fbcdn.net/v/t42.1790-2/278425397_298241472321894_3599380883592611685_n.?_nc_cat=109&ccb=1-7&_nc_sid=cf96c8&_nc_ohc=jz8y1dg5avwAX_JcxrM&_nc_ht=video-lax3-1.xx&oh=00_AT9mxNF5w8PCDL6yINeBWM87OgtBkL6feI5fdyD9OsTz7w&oe=62A7E73B
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
# audio-chunks/chunk1.wav : Well wash.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk10.wav : Schools.
# Error:
# Error:
# audio-chunks/chunk13.wav : And pub.
# audio-chunks/chunk14.wav : Safety.
# audio-chunks/chunk15.wav : An hour.
# audio-chunks/chunk16.wav : Fighting.
# Error:
# audio-chunks/chunk18.wav : Taxes.
# audio-chunks/chunk19.wav : I'm ned lamont.
# Error:
# Error:
# Well wash. Schools. And pub. Safety. An hour. Fighting. Taxes. I'm ned lamont.
# 558899288783243
# https://video-lax3-1.xx.fbcdn.net/v/t42.1790-2/278340582_1116917215755094_6304092115783645241_n.?_nc_cat=104&ccb=1-7&_nc_sid=cf96c8&_nc_ohc=8RtltMQFepAAX8YYY3V&_nc_ht=video-lax3-1.xx&oh=00_AT8otcI4rNYcTpDLIRm-0fS6OOc6igVuRSSI3Tdh7rLalQ&oe=62A7E603
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
# audio-chunks/chunk1.wav : Breaking news now it is official.
# audio-chunks/chunk2.wav : Governor lamont has officially signed into law that bill to suspend kinetic.
# audio-chunks/chunk3.wav : Gas back to you money at the gas tax in at the gas pump.
# audio-chunks/chunk4.wav : I never mind.
# audio-chunks/chunk5.wav : Night crew.
# Error:
# Error:
# Breaking news now it is official. Governor lamont has officially signed into law that bill to suspend kinetic. Gas back to you money at the gas tax in at the gas pump. I never mind. Night crew.
# 428368279057305
# No Video
# 800753051314934
# No Video
# 517254953264936
# https://video-lax3-1.xx.fbcdn.net/v/t42.1790-2/278490122_499251605206385_6845111307357086510_n.?_nc_cat=108&ccb=1-7&_nc_sid=cf96c8&_nc_ohc=I6fmC-2kUwUAX__5rq5&_nc_ht=video-lax3-1.xx&oh=00_AT8ePNsVeL_8rR67f48BkhBlFot3DOgUGxGNsHPqne9ypQ&oe=62A7E94C
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
# audio-chunks/chunk1.wav : America.
# audio-chunks/chunk2.wav : Connecticut was divided.
# Error:
# Error:
# Error:
# audio-chunks/chunk6.wav : Together.
# Error:
# audio-chunks/chunk8.wav : The budget.
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# audio-chunks/chunk17.wav : Alba.
# Error:
# Error:
# audio-chunks/chunk20.wav : Undead lamar.
# Error:
# Error:
# audio-chunks/chunk23.wav : Message.
# America. Connecticut was divided. Together. The budget. Alba. Undead lamar. Message.
# 792382515059143
# No Video
# 1413865522406288
# No Video
# 551302693278134
# No Video
# 3866054930285815
# No Video
# 349960357163559
# No Video
# 399363435061678
# No Video
# 1597617367278424
# No Video
# 397863609009209
# No Video
# 532970818343681
# No Video
# 3890616157830050
# No Video
# 1194800824592610
# No Video
# 1359055137937939
# No Video
# 7322630201141277
# No Video
# 682761356389287
# https://video-lax3-2.xx.fbcdn.net/v/t42.1790-2/278446545_959427481391157_7073745759469550241_n.?_nc_cat=100&ccb=1-7&_nc_sid=cf96c8&_nc_ohc=a6tzcEIwe-EAX8XQ3M2&_nc_ht=video-lax3-2.xx&oh=00_AT-QAETpD3op68J3ghjV_tmAseB40LrDjb6xtfYJgY-XLg&oe=62A7F425
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.
# Error:
# Error:
# audio-chunks/chunk3.wav : And why should i care.
# audio-chunks/chunk4.wav : My first thought of my business..
# Error:
# Error:
# Error:
# Error:
# Error:
# No Video
# 646912693430980
# No Video
# 321315059929782
# No Video
# 7337770182962641
# No Video
# 733437434682893
# No Video
# 530182005128971
# No Video
# 1027204817906708
# No Video
# 496526585475501
# No Video
# 695796751571474
# No Video
# 6158474014171985
# No Video
# 952179542153186
# No Video
# 263360889252893
# No Video
# 738112223879437
# No Video
# 361940595871023
# No Video
# 778424183130853

# %%
df['vid_captions'] = videoCaptions
