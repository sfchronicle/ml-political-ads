# %%
from youtube_transcript_api import YouTubeTranscriptApi
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import json
import spacy
from spacy.matcher import PhraseMatcher

# %%
# function that filter the urls and symbols in the text 
def clean_text(df_text):
    def filter_text(x):
        url = 'http[s]?://\S+'
        x = re.sub(url,'',x)
        x = re.sub("[^\w\s]",' ',x) # filter symbols
        x = re.sub("\s+",' ',x)
        ls=[w.lower() for w in x.split()] 
        return ' '.join(ls)
    df_text['text'] = df_text['text'].astype(str).apply(lambda x: filter_text(x))
    df_text['text'] = df_text['text'].replace('/u0026', ' ')
    df_text.drop_duplicates(subset = 'text',keep = 'first', inplace = True)
    df_text.reset_index(drop = True,inplace = True)
    return df_text

# %%
# the function that find the lexicon words in the text
def find_words(x,lexicon):
    topics= lexicon.keys()  
    nlp = spacy.load('en_core_web_lg')
    doc = nlp(x) # nlp() is spaCy 2.2 English language model 
    words= []
    for t in topics:
        matcher = PhraseMatcher(nlp.vocab)
        terms= lexicon[t]
        patterns = [nlp.make_doc(text) for text in terms]
        matcher.add("TerminologyList", patterns) # spaCy2.2 phrase matcher
        matches = matcher(doc)
        for match_id, start,end in matches:
            span = doc[start:end]
            words.append(span.text)
    if words:
        words = list(set(words))
        return ','.join(words)
    else:
        return('no words')

# %%
# tagging the topic in each message
def find_topic(x,lexicon):
    topics= lexicon.keys()    
    if x=='no words':
        return ''    
    if x != 'no words': 
        words = x.split(',')
        labels = []        
        for t in topics:            
            terms = lexicon[t]
            if set(words)&set(terms):
                labels.append(t)                
                #l = sorted(labels)        
        return  ','.join(sorted(labels))
                
        #return ','.join(labels)

# %%
def get_word_lable(df_text,lexicon):
    with open (lexicon) as f:
        dic = json.load(f)
    df_text['words'] = df_text['text'].astype(str).apply(lambda x: find_words(x,dic))
    df_text['m_label'] = df_text['words'].apply(lambda x: find_topic(x,dic))
    df_text['m_label'] = df_text['m_label'].apply(lambda x: 'no topic' if x=='' else x)
    return df_text

# %%
def count_topic(df_text):
    df_tag = df_text['m_label'].value_counts().rename_axis('topics').reset_index(name='counts')
    df_tag = df_tag.assign(single_topic=df_tag['topics'].str.split(',')).explode('single_topic').reset_index(drop = True)
    df_tag = df_tag.groupby('single_topic').sum().reset_index().sort_values(by = 'counts', ascending = False)
    df_tag.reset_index(drop = True, inplace = True)
    return df_tag

# %%
def count_word(df_text):
    df_words = df_text['words'].value_counts().rename_axis('words').reset_index(name='counts')
    df_words = df_words.assign(single_word=df_words['words'].str.split(',')).explode('single_word').reset_index(drop = True)
    df_words = df_words.groupby('single_word').sum().reset_index().sort_values(by = 'counts', ascending = False)
    df_words.reset_index(drop = True, inplace = True)
    return df_words

# %%
# go through the csv file, get youtube video's ids from all video ads. Add new column 'youtube_id' 
# before running this function, make sure the csv file includes ad_url
def get_youtube_id(fn): 
    df = pd.read_csv(fn)
    df = df[df['ad_type'] == 'Video'].reset_index(drop = True) # only get video ads
    df_video = df[['ad_url','advertiser_name','impressions','spend_usd']].reset_index(drop = True) 
    urls = df_video['ad_url'].to_list() # 
    youtube_ids = [] # get youtube id
    for url in urls:
        entity_id = url.split('/')[-3]
        creative_id = url.split('/')[-1]
        report_url = 'https://transparencyreport.google.com/transparencyreport/api/v3/politicalads/creatives/details?entity_id={}&creative_id={}&hl=en'.format(entity_id,creative_id)
        response = requests.get(report_url)
        try:
            youtube_id = response.text.split('"')[3]
            if len(list(youtube_id)) > 11: # mark ads violating google polices
                youtube_id = 'youtube_id not available: this ad violated google ad policies.' 
            #print(youtube_id + ', ' + creative_id)
        except IndexError: # mark ads cannot be loaded
            youtube_id = 'youtube_id not available: cannot load the video with this ad_url.'
            #print("can't load this video, " + report_url)
            pass
        youtube_ids.append(youtube_id)
    df_video['youtube_id'] = youtube_ids
    return df_video

# %%
# check all videos, see which are available and drop duplicates. Add a new column video_available
def check_video(df_video): 
  for id in df_video['youtube_id']:
    if len(list(id)) == 11:
      df_video.drop_duplicates(subset = 'youtube_id',keep = 'first', inplace = True)
      df_video.reset_index(drop = True, inplace=True)
      yes_video = df_video['youtube_id'].str.len() == 11
      df_video['video_available'] = yes_video
      return df_video

# %%
# use youtube_id to get captions. Add a new column youtube_captions
def get_captions(df_video):
  youtube_captions = []
  for youtube_id in df_video['youtube_id']:
    try:
      subs = YouTubeTranscriptApi.get_transcript(youtube_id)
      alist = []
      for sub in subs:
        alist.append(" " + sub['text'])
      captions = ""
      for item in alist:
        captions += item
    except Exception as e:
      captions = e   
    youtube_captions.append(captions)
  #print(len(youtube_captions))
  df_video['text'] = youtube_captions
  return df_video

# %% [markdown]
# # CA

# %%
ca_video = get_youtube_id('GoogleAds/CA.csv')
ca_video_clean = check_video(ca_video)
ca_captions = get_captions(ca_video_clean)

# %%
# remove Lost Debate and Turning Point
remove_advertiser = ['Lost Debate Inc','TURNING POINT USA, NFP']
ca_captions = ca_captions[-ca_captions['advertiser_name'].isin(remove_advertiser)]
ca_captions
# Out:
#                                                ad_url  \
# 0   https://transparencyreport.google.com/politica...
# 1   https://transparencyreport.google.com/politica...
# 2   https://transparencyreport.google.com/politica...
# 4   https://transparencyreport.google.com/politica...
# 5   https://transparencyreport.google.com/politica...
# 6   https://transparencyreport.google.com/politica...
# 8   https://transparencyreport.google.com/politica...
# 9   https://transparencyreport.google.com/politica...
# 10  https://transparencyreport.google.com/politica...
# 11  https://transparencyreport.google.com/politica...
# 12  https://transparencyreport.google.com/politica...
# 13  https://transparencyreport.google.com/politica...
# 15  https://transparencyreport.google.com/politica...
# 16  https://transparencyreport.google.com/politica...
# 18  https://transparencyreport.google.com/politica...
# 19  https://transparencyreport.google.com/politica...
# 22  https://transparencyreport.google.com/politica...
# 23  https://transparencyreport.google.com/politica...
# 24  https://transparencyreport.google.com/politica...
# 25  https://transparencyreport.google.com/politica...
# 26  https://transparencyreport.google.com/politica...
# 27  https://transparencyreport.google.com/politica...
# 28  https://transparencyreport.google.com/politica...
# 29  https://transparencyreport.google.com/politica...
# 30  https://transparencyreport.google.com/politica...
# 31  https://transparencyreport.google.com/politica...
# 32  https://transparencyreport.google.com/politica...
# 33  https://transparencyreport.google.com/politica...
# 35  https://transparencyreport.google.com/politica...
# 36  https://transparencyreport.google.com/politica...
# 37  https://transparencyreport.google.com/politica...
# 39  https://transparencyreport.google.com/politica...
# 42  https://transparencyreport.google.com/politica...
# 45  https://transparencyreport.google.com/politica...
# 48  https://transparencyreport.google.com/politica...
# 49  https://transparencyreport.google.com/politica...
# 50  https://transparencyreport.google.com/politica...
# 51  https://transparencyreport.google.com/politica...
# 52  https://transparencyreport.google.com/politica...
# 53  https://transparencyreport.google.com/politica...
# 54  https://transparencyreport.google.com/politica...
# 55  https://transparencyreport.google.com/politica...
# 56  https://transparencyreport.google.com/politica...
# 57  https://transparencyreport.google.com/politica...
# 59  https://transparencyreport.google.com/politica...
# 60  https://transparencyreport.google.com/politica...
# 61  https://transparencyreport.google.com/politica...
# 62  https://transparencyreport.google.com/politica...
# 65  https://transparencyreport.google.com/politica...
#
#                                       advertiser_name impressions spend_usd  \
# 0                                    SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 1                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 2                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 4                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 5                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 6                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 8                                    SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 9                                                NRSC       ≤ 10k     ≤ 100
# 10                   MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 11            NEWSOM FOR CALIFORNIA – GOVERNOR – 2022       ≤ 10k     ≤ 100
# 12                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 13                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 15                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 16                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 18                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 19                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 22             RESOURCE MEDIA A NONPROFIT CORPORATION       ≤ 10k     ≤ 100
# 23                                     Vincent Collis    10k-100k     ≤ 100
# 24  Californians for Solutions to Homelessness and...      1M-10M    1k-50k
# 25                              MARK KELLY FOR SENATE     100k-1M    1k-50k
# 26                                RO FOR CONGRESS INC    10k-100k    1k-50k
# 27            NEWSOM FOR CALIFORNIA – GOVERNOR – 2022    10k-100k    100-1k
# 28  Californians for Solutions to Homelessness and...       ≤ 10k    100-1k
# 29            NEWSOM FOR CALIFORNIA – GOVERNOR – 2022    10k-100k    100-1k
# 30                      MORE PERFECT UNION FOUNDATION    10k-100k     ≤ 100
# 31            NEWSOM FOR CALIFORNIA – GOVERNOR – 2022    10k-100k    100-1k
# 32                                   SAHAK NALBANDYAN    10k-100k    100-1k
# 33                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 35                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 36                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 37                   MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 39                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 42                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 45                                     Vincent Collis    10k-100k     ≤ 100
# 48                              MARK KELLY FOR SENATE     100k-1M    1k-50k
# 49  Coalition for Safe, Responsible Gaming, Sponso...     100k-1M    1k-50k
# 50                    SHELLENBERGER FOR GOVERNOR 2022    10k-100k    100-1k
# 51                 UNION OF CONCERNED SCIENTISTS. INC    10k-100k    100-1k
# 52                                    BARRY FRIEDLAND    10k-100k    100-1k
# 53                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 54                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 55                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 56                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 57                                           Adam Lui       ≤ 10k     ≤ 100
# 59                                               NRSC       ≤ 10k     ≤ 100
# 60                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 61                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 62             RESOURCE MEDIA A NONPROFIT CORPORATION       ≤ 10k     ≤ 100
# 65                          KATIE PORTER FOR CONGRESS    10k-100k    100-1k
#
#      youtube_id  video_available  \
# 0   pzLwTOpn9mc             True
# 1   C0Bwn5e2Fqc             True
# 2   O8v9Nk_PKpM             True
# 4   phLp03VtiSg             True
# 5   IUQYgYSl0Pc             True
# 6   VsNmklD4Lkk             True
# 8   8Fj9aEnCZq0             True
# 9   Yg5eDw33DFk             True
# 10  n8p9bcRbLxs             True
# 11  gwuPy9FiaIA             True
# 12  AZvpN60L7TQ             True
# 13  MAYn8z1nWns             True
# 15  gCTKmNOuNG4             True
# 16  coAMYFxZ6Y0             True
# 18  XkIMuyIo0Ho             True
# 19  lbIsDuWUKU0             True
# 22  ixoTIKDbgEs             True
# 23  lEy_YM4iLTY             True
# 24  kIG0H3ZLsK0             True
# 25  3T562KcnM4M             True
# 26  7A_rBIQbwJ0             True
# 27  qmGQORB4Q0E             True
# 28  VwNb2oRP2uk             True
# 29  xBWazJj9o9U             True
# 30  fiLusO7JopQ             True
# 31  GI7_YITXOXQ             True
# 32  fOCUqnSVIFY             True
# 33  H8lm7S6JyXg             True
# 35  rIsJ_Se_chQ             True
# 36  fI_ZdUtgRkA             True
# 37  jG6NGdLUHeM             True
# 39  o2fdtPz4IG8             True
# 42  mvWkW8tA8J8             True
# 45  PzJHoQBVkJY             True
# 48  i520e3hLRyU             True
# 49  9ZOTCSzUrF4             True
# 50  TUmxAx8Bw7Y             True
# 51  OP4jgQhBlpc             True
# 52  VljKJnaK4uQ             True
# 53  J4Fuj4XEoKY             True
# 54  NEHcQ116M2c             True
# 55  LfR1ppYBggY             True
# 56  F_r5KOqhBa0             True
# 57  ARMw3E60Dp4             True
# 59  I3qTGRBM1Vg             True
# 60  2OWY79gGeUE             True
# 61  oUsczCvbVDw             True
# 62  ZFsQpVfsBro             True
# 65  L5y4VxGyQ2s             True
#
#                                                  text
# 0    morgan president biden opened the leaders sum...
# 1    [Music] [Music] all right hello and welcome a...
# 2    i am a big uh supporter of the highway 37 exp...
# 4    hello and welcome everyone to another episode...
# 5    yeah kind of as as we're kind of coming to a ...
# 6    like i said you know we're still in the midst...
# 8    attention homeowners if you have a meter like...
# 9   \nCould not retrieve a transcript for the vide...
# 10  \nCould not retrieve a transcript for the vide...
# 11   hey everybody it's gavin and i can't believe ...
# 12   kind of i guess how did your like working for...
# 13   yeah i guess you know something you touched u...
# 15   hello and welcome again to another episode of...
# 16   hello and welcome again to another episode of...
# 18   [Music] okay that's great you know what one t...
# 19   well not only for my district but for the who...
# 22   the buildback better act is our best chance p...
# 23   okay let's get started you talk about your mo...
# 24   california is in a state of emergency the cal...
# 25   [Music] in the navy i learned how hard a day'...
# 26   HEY EVERYBODY WELCOME BACK\nTO THE LATE SHOW ...
# 27   it's hard for me to even say this with the re...
# 28   [Music] california is in a state of emergency...
# 29   i can't believe it it's finally here our firs...
# 30   what you're seeing around the country is alre...
# 31   it's hard for me to even say this with the re...
# 32   if you've thought about going solar i want yo...
# 33   from you know your your union background i gu...
# 35   hello and welcome to another episode of sac t...
# 36   i guess running for office and kind of workin...
# 37   general michael flynn was unmasked at least 4...
# 39   you know you know college football season has...
# 42   so kind of i guess kind of turning to like th...
# 45   riley casey are you making a commercial again...
# 48   arizonans know lots of things need fixing not...
# 49   out-of-state gambling corporations are pushin...
# 50   california is in a crisis of chaos we won't r...
# 51   in times of crisis we need leadership sober l...
# 52   well sb 286 has nothing to do with election c...
# 53   [Music] [Music] hello and welcome to another ...
# 54   how i guess how are your cities doing coming ...
# 55   okay you ready to go wait okay go ahead okay ...
# 56   [Music] [Music] hello and welcome again to an...
# 57   i trusted our governor i trusted my commissio...
# 59  \nCould not retrieve a transcript for the vide...
# 60   and the theory here is that um there were two...
# 61   hello and welcome again to another episode of...
# 62   My life before, was like a train wreck, is th...
# 65   hi it's representative katie porter i wanted ...

# %%
# remove unavialable videos
ca_captions = ca_captions[ca_captions['video_available'] == True]
ca_captions_clean = clean_text(ca_captions)
ca_captions_clean
# Out:
#                                                ad_url  \
# 0   https://transparencyreport.google.com/politica...
# 1   https://transparencyreport.google.com/politica...
# 2   https://transparencyreport.google.com/politica...
# 3   https://transparencyreport.google.com/politica...
# 4   https://transparencyreport.google.com/politica...
# 5   https://transparencyreport.google.com/politica...
# 6   https://transparencyreport.google.com/politica...
# 7   https://transparencyreport.google.com/politica...
# 8   https://transparencyreport.google.com/politica...
# 9   https://transparencyreport.google.com/politica...
# 10  https://transparencyreport.google.com/politica...
# 11  https://transparencyreport.google.com/politica...
# 12  https://transparencyreport.google.com/politica...
# 13  https://transparencyreport.google.com/politica...
# 14  https://transparencyreport.google.com/politica...
# 15  https://transparencyreport.google.com/politica...
# 16  https://transparencyreport.google.com/politica...
# 17  https://transparencyreport.google.com/politica...
# 18  https://transparencyreport.google.com/politica...
# 19  https://transparencyreport.google.com/politica...
# 20  https://transparencyreport.google.com/politica...
# 21  https://transparencyreport.google.com/politica...
# 22  https://transparencyreport.google.com/politica...
# 23  https://transparencyreport.google.com/politica...
# 24  https://transparencyreport.google.com/politica...
# 25  https://transparencyreport.google.com/politica...
# 26  https://transparencyreport.google.com/politica...
# 27  https://transparencyreport.google.com/politica...
# 28  https://transparencyreport.google.com/politica...
# 29  https://transparencyreport.google.com/politica...
# 30  https://transparencyreport.google.com/politica...
# 31  https://transparencyreport.google.com/politica...
# 32  https://transparencyreport.google.com/politica...
# 33  https://transparencyreport.google.com/politica...
# 34  https://transparencyreport.google.com/politica...
# 35  https://transparencyreport.google.com/politica...
# 36  https://transparencyreport.google.com/politica...
# 37  https://transparencyreport.google.com/politica...
# 38  https://transparencyreport.google.com/politica...
# 39  https://transparencyreport.google.com/politica...
# 40  https://transparencyreport.google.com/politica...
# 41  https://transparencyreport.google.com/politica...
# 42  https://transparencyreport.google.com/politica...
# 43  https://transparencyreport.google.com/politica...
# 44  https://transparencyreport.google.com/politica...
# 45  https://transparencyreport.google.com/politica...
# 46  https://transparencyreport.google.com/politica...
#
#                                       advertiser_name impressions spend_usd  \
# 0                                    SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 1                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 2                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 3                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 4                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 5                                     JARHETT BLONIEN       ≤ 10k     ≤ 100
# 6                                    SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 7                                                NRSC       ≤ 10k     ≤ 100
# 8                    MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 9             NEWSOM FOR CALIFORNIA – GOVERNOR – 2022       ≤ 10k     ≤ 100
# 10                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 11                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 12                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 13                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 14                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 15                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 16             RESOURCE MEDIA A NONPROFIT CORPORATION       ≤ 10k     ≤ 100
# 17                                     Vincent Collis    10k-100k     ≤ 100
# 18  Californians for Solutions to Homelessness and...      1M-10M    1k-50k
# 19                              MARK KELLY FOR SENATE     100k-1M    1k-50k
# 20                                RO FOR CONGRESS INC    10k-100k    1k-50k
# 21            NEWSOM FOR CALIFORNIA – GOVERNOR – 2022    10k-100k    100-1k
# 22  Californians for Solutions to Homelessness and...       ≤ 10k    100-1k
# 23            NEWSOM FOR CALIFORNIA – GOVERNOR – 2022    10k-100k    100-1k
# 24                      MORE PERFECT UNION FOUNDATION    10k-100k     ≤ 100
# 25                                   SAHAK NALBANDYAN    10k-100k    100-1k
# 26                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 27                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 28                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 29                   MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 30                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 31                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 32                                     Vincent Collis    10k-100k     ≤ 100
# 33                              MARK KELLY FOR SENATE     100k-1M    1k-50k
# 34  Coalition for Safe, Responsible Gaming, Sponso...     100k-1M    1k-50k
# 35                    SHELLENBERGER FOR GOVERNOR 2022    10k-100k    100-1k
# 36                 UNION OF CONCERNED SCIENTISTS. INC    10k-100k    100-1k
# 37                                    BARRY FRIEDLAND    10k-100k    100-1k
# 38                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 39                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 40                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 41                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 42                                           Adam Lui       ≤ 10k     ≤ 100
# 43                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 44                                    JARHETT BLONIEN       ≤ 10k     ≤ 100
# 45             RESOURCE MEDIA A NONPROFIT CORPORATION       ≤ 10k     ≤ 100
# 46                          KATIE PORTER FOR CONGRESS    10k-100k    100-1k
#
#      youtube_id  video_available  \
# 0   pzLwTOpn9mc             True
# 1   C0Bwn5e2Fqc             True
# 2   O8v9Nk_PKpM             True
# 3   phLp03VtiSg             True
# 4   IUQYgYSl0Pc             True
# 5   VsNmklD4Lkk             True
# 6   8Fj9aEnCZq0             True
# 7   Yg5eDw33DFk             True
# 8   n8p9bcRbLxs             True
# 9   gwuPy9FiaIA             True
# 10  AZvpN60L7TQ             True
# 11  MAYn8z1nWns             True
# 12  gCTKmNOuNG4             True
# 13  coAMYFxZ6Y0             True
# 14  XkIMuyIo0Ho             True
# 15  lbIsDuWUKU0             True
# 16  ixoTIKDbgEs             True
# 17  lEy_YM4iLTY             True
# 18  kIG0H3ZLsK0             True
# 19  3T562KcnM4M             True
# 20  7A_rBIQbwJ0             True
# 21  qmGQORB4Q0E             True
# 22  VwNb2oRP2uk             True
# 23  xBWazJj9o9U             True
# 24  fiLusO7JopQ             True
# 25  fOCUqnSVIFY             True
# 26  H8lm7S6JyXg             True
# 27  rIsJ_Se_chQ             True
# 28  fI_ZdUtgRkA             True
# 29  jG6NGdLUHeM             True
# 30  o2fdtPz4IG8             True
# 31  mvWkW8tA8J8             True
# 32  PzJHoQBVkJY             True
# 33  i520e3hLRyU             True
# 34  9ZOTCSzUrF4             True
# 35  TUmxAx8Bw7Y             True
# 36  OP4jgQhBlpc             True
# 37  VljKJnaK4uQ             True
# 38  J4Fuj4XEoKY             True
# 39  NEHcQ116M2c             True
# 40  LfR1ppYBggY             True
# 41  F_r5KOqhBa0             True
# 42  ARMw3E60Dp4             True
# 43  2OWY79gGeUE             True
# 44  oUsczCvbVDw             True
# 45  ZFsQpVfsBro             True
# 46  L5y4VxGyQ2s             True
#
#                                                  text
# 0   morgan president biden opened the leaders summ...
# 1   music music all right hello and welcome again ...
# 2   i am a big uh supporter of the highway 37 expa...
# 3   hello and welcome everyone to another episode ...
# 4   yeah kind of as as we re kind of coming to a c...
# 5   like i said you know we re still in the midst ...
# 6   attention homeowners if you have a meter like ...
# 7   could not retrieve a transcript for the video ...
# 8   could not retrieve a transcript for the video ...
# 9   hey everybody it s gavin and i can t believe i...
# 10  kind of i guess how did your like working for ...
# 11  yeah i guess you know something you touched up...
# 12  hello and welcome again to another episode of ...
# 13  hello and welcome again to another episode of ...
# 14  music okay that s great you know what one thin...
# 15  well not only for my district but for the whol...
# 16  the buildback better act is our best chance pe...
# 17  okay let s get started you talk about your mot...
# 18  california is in a state of emergency the cali...
# 19  music in the navy i learned how hard a day s w...
# 20  hey everybody welcome back to the late show fo...
# 21  it s hard for me to even say this with the rec...
# 22  music california is in a state of emergency th...
# 23  i can t believe it it s finally here our first...
# 24  what you re seeing around the country is alrea...
# 25  if you ve thought about going solar i want you...
# 26  from you know your your union background i gue...
# 27  hello and welcome to another episode of sac to...
# 28  i guess running for office and kind of working...
# 29  general michael flynn was unmasked at least 48...
# 30  you know you know college football season has ...
# 31  so kind of i guess kind of turning to like the...
# 32  riley casey are you making a commercial again ...
# 33  arizonans know lots of things need fixing not ...
# 34  out of state gambling corporations are pushing...
# 35  california is in a crisis of chaos we won t re...
# 36  in times of crisis we need leadership sober le...
# 37  well sb 286 has nothing to do with election co...
# 38  music music hello and welcome to another episo...
# 39  how i guess how are your cities doing coming o...
# 40  okay you ready to go wait okay go ahead okay a...
# 41  music music hello and welcome again to another...
# 42  i trusted our governor i trusted my commission...
# 43  and the theory here is that um there were two ...
# 44  hello and welcome again to another episode of ...
# 45  my life before was like a train wreck is the b...
# 46  hi it s representative katie porter i wanted t...

# %%
ca_captions_tagged = get_word_lable(ca_captions_clean,'lexicon.json')
ca_captions_tagged
ca_captions_tagged.to_csv('ca_captions_tagged.csv')

# %%
ca_topic = count_topic(ca_captions_tagged)
ca_topic
# Out:
#                single_topic  counts
# 0                  economic      25
# 1                    health      20
# 2                governance      18
# 3                 education      17
# 4       social and cultural      17
# 5                    safety      17
# 6               environment      15
# 7                     covid      13
# 8           social programs      13
# 9   continue with the folks      10
# 10           foreign policy      10
# 11            establishment       8
# 12              immigration       7
# 13                 donation       6
# 14                 military       4
# 15               polarizing       4
# 16                 no topic       3
# 17               supporters       3

# %%
ca_word = count_word(ca_captions_tagged)
ca_word
# Out:
#                 single_word  counts
# 0                    health      18
# 1                    school      13
# 2                       law      11
# 3                      jobs      10
# 4                  pandemic      10
# ..                      ...     ...
# 249      immigration reform       1
# 250              in poverty       1
# 251             instability       1
# 252       insurance company       1
# 253  young african american       1
#
# [254 rows x 2 columns]

# %%
ca_captions_tagged['advertiser_name'].value_counts()
# Out:
# JARHETT BLONIEN                                                                                                                                                                                      22
# SAHAK NALBANDYAN                                                                                                                                                                                      3
# NEWSOM FOR CALIFORNIA – GOVERNOR – 2022                                                                                                                                                               3
# Vincent Collis                                                                                                                                                                                        2
# Californians for Solutions to Homelessness and Mental Health Support, a Coalition of Housing and Mental Health Experts, Concerned Taxpayers and Digital Sports Entertainment and Gaming Companies     2
# MARK KELLY FOR SENATE                                                                                                                                                                                 2
# RESOURCE MEDIA A NONPROFIT CORPORATION                                                                                                                                                                2
# MARKETFUEL SUBSCRIPTION SERVICES                                                                                                                                                                      2
# NRSC                                                                                                                                                                                                  1
# RO FOR CONGRESS INC                                                                                                                                                                                   1
# MORE PERFECT UNION FOUNDATION                                                                                                                                                                         1
# Coalition for Safe, Responsible Gaming, Sponsored by California Indian Tribes                                                                                                                         1
# SHELLENBERGER FOR GOVERNOR 2022                                                                                                                                                                       1
# UNION OF CONCERNED SCIENTISTS. INC                                                                                                                                                                    1
# BARRY FRIEDLAND                                                                                                                                                                                       1
# Adam Lui                                                                                                                                                                                              1
# KATIE PORTER FOR CONGRESS                                                                                                                                                                             1
# Name: advertiser_name, dtype: int64

# %% [markdown]
# # TX

# %%
tx_video = get_youtube_id('GoogleAds/texas.csv')
tx_video_clean = check_video(tx_video)
tx_captions = get_captions(tx_video_clean)
tx_captions
# Out:
#                                                 ad_url  \
# 0    https://transparencyreport.google.com/politica...
# 1    https://transparencyreport.google.com/politica...
# 2    https://transparencyreport.google.com/politica...
# 3    https://transparencyreport.google.com/politica...
# 4    https://transparencyreport.google.com/politica...
# ..                                                 ...
# 151  https://transparencyreport.google.com/politica...
# 152  https://transparencyreport.google.com/politica...
# 153  https://transparencyreport.google.com/politica...
# 154  https://transparencyreport.google.com/politica...
# 155  https://transparencyreport.google.com/politica...
#
#                                      advertiser_name impressions spend_usd  \
# 0                                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 1                                          Chad Crow       ≤ 10k     ≤ 100
# 2                             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 3                                         Allen West       ≤ 10k     ≤ 100
# 4                      JESSICA CISNEROS FOR CONGRESS       ≤ 10k     ≤ 100
# ..                                               ...         ...       ...
# 151                              Hohman for Congress    10k-100k    100-1k
# 152                                    John N. Raney    10k-100k    100-1k
# 153  TEXANS FOR HENRY CUELLAR CONGRESSIONAL CAMPAIGN    10k-100k    100-1k
# 154           Doctor Matt Rostami For Texas Campaign    10k-100k    100-1k
# 155                                          BRIXIUS    10k-100k    100-1k
#
#                                             youtube_id  video_available  \
# 0                                          pzLwTOpn9mc             True
# 1                                          7ne91Qj4XEo             True
# 2    youtube_id not available: cannot load the vide...            False
# 3                                          9i4lMGfNTRA             True
# 4                                          B1ozJ2JH8BE             True
# ..                                                 ...              ...
# 151                                        8Jf4sxrOkzo             True
# 152                                        _Ff2-uWTpl0             True
# 153                                        idEsiU0jBiA             True
# 154                                        4ynkJPbh4Ns             True
# 155                                        lLaoeBgQCSk             True
#
#                                                   text
# 0     morgan president biden opened the leaders sum...
# 1     i believe that free and fair elections are on...
# 2    \nCould not retrieve a transcript for the vide...
# 3     hey i'm ted nugent full-time i'm addicted to ...
# 4     tonight fbi agents at the home of henry cuell...
# ..                                                 ...
# 151   you know the drone is overhead but you can't ...
# 152   texans can count on john rainey rainey is fig...
# 153   [Music] get up early work hard my parents sai...
# 154   to grow the republican party we're going to n...
# 155   let's keep republican lin finley working for ...
#
# [156 rows x 7 columns]

# %%
remove_advertiser = ['Lost Debate Inc','TURNING POINT USA, NFP']
tx_captions = tx_captions[-tx_captions['advertiser_name'].isin(remove_advertiser)]
tx_captions
# Out:
#                                                 ad_url  \
# 0    https://transparencyreport.google.com/politica...
# 1    https://transparencyreport.google.com/politica...
# 3    https://transparencyreport.google.com/politica...
# 4    https://transparencyreport.google.com/politica...
# 5    https://transparencyreport.google.com/politica...
# ..                                                 ...
# 151  https://transparencyreport.google.com/politica...
# 152  https://transparencyreport.google.com/politica...
# 153  https://transparencyreport.google.com/politica...
# 154  https://transparencyreport.google.com/politica...
# 155  https://transparencyreport.google.com/politica...
#
#                                      advertiser_name impressions spend_usd  \
# 0                                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 1                                          Chad Crow       ≤ 10k     ≤ 100
# 3                                         Allen West       ≤ 10k     ≤ 100
# 4                      JESSICA CISNEROS FOR CONGRESS       ≤ 10k     ≤ 100
# 5                      JESSICA CISNEROS FOR CONGRESS       ≤ 10k     ≤ 100
# ..                                               ...         ...       ...
# 151                              Hohman for Congress    10k-100k    100-1k
# 152                                    John N. Raney    10k-100k    100-1k
# 153  TEXANS FOR HENRY CUELLAR CONGRESSIONAL CAMPAIGN    10k-100k    100-1k
# 154           Doctor Matt Rostami For Texas Campaign    10k-100k    100-1k
# 155                                          BRIXIUS    10k-100k    100-1k
#
#       youtube_id  video_available  \
# 0    pzLwTOpn9mc             True
# 1    7ne91Qj4XEo             True
# 3    9i4lMGfNTRA             True
# 4    B1ozJ2JH8BE             True
# 5    noinAynqn28             True
# ..           ...              ...
# 151  8Jf4sxrOkzo             True
# 152  _Ff2-uWTpl0             True
# 153  idEsiU0jBiA             True
# 154  4ynkJPbh4Ns             True
# 155  lLaoeBgQCSk             True
#
#                                                   text
# 0     morgan president biden opened the leaders sum...
# 1     i believe that free and fair elections are on...
# 3     hey i'm ted nugent full-time i'm addicted to ...
# 4     tonight fbi agents at the home of henry cuell...
# 5    \nCould not retrieve a transcript for the vide...
# ..                                                 ...
# 151   you know the drone is overhead but you can't ...
# 152   texans can count on john rainey rainey is fig...
# 153   [Music] get up early work hard my parents sai...
# 154   to grow the republican party we're going to n...
# 155   let's keep republican lin finley working for ...
#
# [137 rows x 7 columns]

# %%
# remove unavialable videos and clean texts
tx_captions_available = tx_captions[tx_captions['video_available'] == True]
tx_captions_clean = clean_text(tx_captions_available)
tx_captions_clean
# Out:
#                                                 ad_url  \
# 0    https://transparencyreport.google.com/politica...
# 1    https://transparencyreport.google.com/politica...
# 2    https://transparencyreport.google.com/politica...
# 3    https://transparencyreport.google.com/politica...
# 4    https://transparencyreport.google.com/politica...
# ..                                                 ...
# 120  https://transparencyreport.google.com/politica...
# 121  https://transparencyreport.google.com/politica...
# 122  https://transparencyreport.google.com/politica...
# 123  https://transparencyreport.google.com/politica...
# 124  https://transparencyreport.google.com/politica...
#
#                                      advertiser_name impressions spend_usd  \
# 0                                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 1                                          Chad Crow       ≤ 10k     ≤ 100
# 2                                         Allen West       ≤ 10k     ≤ 100
# 3                      JESSICA CISNEROS FOR CONGRESS       ≤ 10k     ≤ 100
# 4                      JESSICA CISNEROS FOR CONGRESS       ≤ 10k     ≤ 100
# ..                                               ...         ...       ...
# 120                              Hohman for Congress    10k-100k    100-1k
# 121                                    John N. Raney    10k-100k    100-1k
# 122  TEXANS FOR HENRY CUELLAR CONGRESSIONAL CAMPAIGN    10k-100k    100-1k
# 123           Doctor Matt Rostami For Texas Campaign    10k-100k    100-1k
# 124                                          BRIXIUS    10k-100k    100-1k
#
#       youtube_id  video_available  \
# 0    pzLwTOpn9mc             True
# 1    7ne91Qj4XEo             True
# 2    9i4lMGfNTRA             True
# 3    B1ozJ2JH8BE             True
# 4    noinAynqn28             True
# ..           ...              ...
# 120  8Jf4sxrOkzo             True
# 121  _Ff2-uWTpl0             True
# 122  idEsiU0jBiA             True
# 123  4ynkJPbh4Ns             True
# 124  lLaoeBgQCSk             True
#
#                                                   text
# 0    morgan president biden opened the leaders summ...
# 1    i believe that free and fair elections are one...
# 2    hey i m ted nugent full time i m addicted to f...
# 3    tonight fbi agents at the home of henry cuella...
# 4    could not retrieve a transcript for the video ...
# ..                                                 ...
# 120  you know the drone is overhead but you can t h...
# 121  texans can count on john rainey rainey is figh...
# 122  music get up early work hard my parents said t...
# 123  to grow the republican party we re going to ne...
# 124  let s keep republican lin finley working for u...
#
# [125 rows x 7 columns]

# %%
tx_captions_tagged = get_word_lable(tx_captions_clean,'lexicon.json')
tx_captions_tagged
# Out:
#                                                 ad_url  \
# 0    https://transparencyreport.google.com/politica...
# 1    https://transparencyreport.google.com/politica...
# 2    https://transparencyreport.google.com/politica...
# 3    https://transparencyreport.google.com/politica...
# 4    https://transparencyreport.google.com/politica...
# ..                                                 ...
# 120  https://transparencyreport.google.com/politica...
# 121  https://transparencyreport.google.com/politica...
# 122  https://transparencyreport.google.com/politica...
# 123  https://transparencyreport.google.com/politica...
# 124  https://transparencyreport.google.com/politica...
#
#                                      advertiser_name impressions spend_usd  \
# 0                                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 1                                          Chad Crow       ≤ 10k     ≤ 100
# 2                                         Allen West       ≤ 10k     ≤ 100
# 3                      JESSICA CISNEROS FOR CONGRESS       ≤ 10k     ≤ 100
# 4                      JESSICA CISNEROS FOR CONGRESS       ≤ 10k     ≤ 100
# ..                                               ...         ...       ...
# 120                              Hohman for Congress    10k-100k    100-1k
# 121                                    John N. Raney    10k-100k    100-1k
# 122  TEXANS FOR HENRY CUELLAR CONGRESSIONAL CAMPAIGN    10k-100k    100-1k
# 123           Doctor Matt Rostami For Texas Campaign    10k-100k    100-1k
# 124                                          BRIXIUS    10k-100k    100-1k
#
#       youtube_id  video_available  \
# 0    pzLwTOpn9mc             True
# 1    7ne91Qj4XEo             True
# 2    9i4lMGfNTRA             True
# 3    B1ozJ2JH8BE             True
# 4    noinAynqn28             True
# ..           ...              ...
# 120  8Jf4sxrOkzo             True
# 121  _Ff2-uWTpl0             True
# 122  idEsiU0jBiA             True
# 123  4ynkJPbh4Ns             True
# 124  lLaoeBgQCSk             True
#
#                                                   text  \
# 0    morgan president biden opened the leaders summ...
# 1    i believe that free and fair elections are one...
# 2    hey i m ted nugent full time i m addicted to f...
# 3    tonight fbi agents at the home of henry cuella...
# 4    could not retrieve a transcript for the video ...
# ..                                                 ...
# 120  you know the drone is overhead but you can t h...
# 121  texans can count on john rainey rainey is figh...
# 122  music get up early work hard my parents said t...
# 123  to grow the republican party we re going to ne...
# 124  let s keep republican lin finley working for u...
#
#                                                  words  \
# 0    transportation,greenhouse,pollution,economic i...
# 1              election integrity,continue,voter fraud
# 2              constitution,continue,addicted,stand up
# 3           corruption,fbi agents,washington,interests
# 4               persian,estonian,turkish,khmer,kurdish
# ..                                                 ...
# 120  guns,police,secure the border,border,vaccine,w...
# 121        police,liberal,secure the border,border,law
# 122  border security,middle class,border,tax,health...
# 123  insurance companies,health,expand medicaid,oba...
# 124         endorsed,taxpayers,business leaders,values
#
#                                                m_label
# 0                          economic,environment,health
# 1                   continue with the folks,governance
# 2    continue with the folks,establishment,governan...
# 3                      establishment,governance,safety
# 4                                       foreign policy
# ..                                                 ...
# 120  covid,establishment,foreign policy,governance,...
# 121           governance,immigration,polarizing,safety
# 122  economic,establishment,governance,health,immig...
# 123                             health,social programs
# 124                     economic,polarizing,supporters
#
# [125 rows x 9 columns]

# %%
tx_captions_tagged.to_csv('tx_captions_tagged.csv')

# %%
count_topic(tx_captions_tagged)
# Out:
#                single_topic  counts
# 0                governance      48
# 1                  economic      35
# 2               immigration      29
# 3                polarizing      22
# 4       social and cultural      21
# 5                    safety      20
# 6                    health      19
# 7             establishment      19
# 8            foreign policy      17
# 9               environment      13
# 10          social programs      12
# 11                education      12
# 12  continue with the folks      11
# 13                 no topic      10
# 14                    covid       7
# 15               supporters       6
# 16                 donation       4
# 17                 military       2

# %%
count_word(tx_captions_tagged)
# Out:
#            single_word  counts
# 0                  law      30
# 1               border      26
# 2               values      12
# 3           washington      11
# 4                taxes      11
# ..                 ...     ...
# 200       million jobs       1
# 201         fbi agents       1
# 202  federal overreach       1
# 203    finish the wall       1
# 204       power plants       1
#
# [205 rows x 2 columns]

# %%
tx_captions_tagged['advertiser_name'].value_counts()
# Out:
# Chad Crow                                            21
# Beto for Texas                                       12
# BRIXIUS                                              12
# TEXANS FOR HENRY CUELLAR CONGRESSIONAL CAMPAIGN       8
# Doctor Matt Rostami For Texas Campaign                7
# C&B Printing Co Inc                                   6
# JESSICA CISNEROS FOR CONGRESS                         5
# John N. Raney                                         5
# GREG CASAR FOR CONGRESS                               5
# OKPA FOR CONGRESS                                     5
# Hohman for Congress                                   3
# SAHAK NALBANDYAN                                      3
# J STREET                                              3
# RESOURCE MEDIA A NONPROFIT CORPORATION                3
# NRCC                                                  3
# Allen West                                            2
# MONICA DE LA CRUZ HERNANDEZ FOR US CONGRESS           2
# MARKETFUEL SUBSCRIPTION SERVICES                      2
# KEN PAXTON CAMPAIGN                                   2
# Glenn A. Hegar                                        2
# ROGER WILLIAMS FOR U S CONGRESS COMMITTEE             2
# Texans for Greg Abbott                                1
# Campaign for Kelly Higgins for District Attorney      1
# NetChoice                                             1
# BETTER JOBS TOGETHER CAMPAIGN                         1
# Team Herschel, Inc.                                   1
# JAY KLEBERG CAMPAIGN FOR TEXAS LAND COMMISSIONER      1
# MATT KRAUSE CAMPAIGN                                  1
# REP. COLIN ALLRED - U.S. HOUSE OF REPRESENTATIVES     1
# MORE PERFECT UNION FOUNDATION                         1
# NRSC                                                  1
# Ad Empower Network                                    1
# Special Operations for America                        1
# Name: advertiser_name, dtype: int64

# %% [markdown]
# # NY

# %%
ny_video = get_youtube_id('GoogleAds/NY.csv')
ny_video_clean = check_video(ny_video)
ny_captions = get_captions(ny_video_clean)
ny_captions
# Out:
#                                                ad_url  \
# 0   https://transparencyreport.google.com/politica...
# 1   https://transparencyreport.google.com/politica...
# 2   https://transparencyreport.google.com/politica...
# 3   https://transparencyreport.google.com/politica...
# 4   https://transparencyreport.google.com/politica...
# 5   https://transparencyreport.google.com/politica...
# 6   https://transparencyreport.google.com/politica...
# 7   https://transparencyreport.google.com/politica...
# 8   https://transparencyreport.google.com/politica...
# 9   https://transparencyreport.google.com/politica...
# 10  https://transparencyreport.google.com/politica...
# 11  https://transparencyreport.google.com/politica...
# 12  https://transparencyreport.google.com/politica...
# 13  https://transparencyreport.google.com/politica...
# 14  https://transparencyreport.google.com/politica...
# 15  https://transparencyreport.google.com/politica...
# 16  https://transparencyreport.google.com/politica...
# 17  https://transparencyreport.google.com/politica...
# 18  https://transparencyreport.google.com/politica...
# 19  https://transparencyreport.google.com/politica...
# 20  https://transparencyreport.google.com/politica...
# 21  https://transparencyreport.google.com/politica...
# 22  https://transparencyreport.google.com/politica...
# 23  https://transparencyreport.google.com/politica...
# 24  https://transparencyreport.google.com/politica...
# 25  https://transparencyreport.google.com/politica...
# 26  https://transparencyreport.google.com/politica...
# 27  https://transparencyreport.google.com/politica...
# 28  https://transparencyreport.google.com/politica...
# 29  https://transparencyreport.google.com/politica...
# 30  https://transparencyreport.google.com/politica...
# 31  https://transparencyreport.google.com/politica...
# 32  https://transparencyreport.google.com/politica...
# 33  https://transparencyreport.google.com/politica...
# 34  https://transparencyreport.google.com/politica...
# 35  https://transparencyreport.google.com/politica...
# 36  https://transparencyreport.google.com/politica...
# 37  https://transparencyreport.google.com/politica...
# 38  https://transparencyreport.google.com/politica...
# 39  https://transparencyreport.google.com/politica...
# 40  https://transparencyreport.google.com/politica...
# 41  https://transparencyreport.google.com/politica...
# 42  https://transparencyreport.google.com/politica...
# 43  https://transparencyreport.google.com/politica...
# 44  https://transparencyreport.google.com/politica...
# 45  https://transparencyreport.google.com/politica...
# 46  https://transparencyreport.google.com/politica...
# 47  https://transparencyreport.google.com/politica...
# 48  https://transparencyreport.google.com/politica...
#
#                                      advertiser_name impressions spend_usd  \
# 0                             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 1                             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 2                                    Lost Debate Inc       ≤ 10k     ≤ 100
# 3                                ZELDIN FOR NEW YORK       ≤ 10k     ≤ 100
# 4                           Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 5                   MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 6                           Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 7                             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 8                                    Lost Debate Inc       ≤ 10k     ≤ 100
# 9                                    Lost Debate Inc       ≤ 10k     ≤ 100
# 10                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 11                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 12                                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 13                                   Sabbath Lafleur       ≤ 10k     ≤ 100
# 14                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 15                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 16                                        Ned for CT      1M-10M    1k-50k
# 17                          TAXPAYERS FOR WILSON INC     100k-1M    1k-50k
# 18                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 19                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 20  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 21              Alliance for Justice Action Campaign    10k-100k    1k-50k
# 22                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 23                           AMERICAN ACTION NETWORK     100k-1M    1k-50k
# 24  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 25                               ZELDIN FOR NEW YORK     100k-1M    1k-50k
# 26                                          1111 LLC     100k-1M    1k-50k
# 27                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 28                          Friends for Kathy Hochul    10k-100k    100-1k
# 29                            TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 30                          Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 31                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 32                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 33                               ZELDIN FOR NEW YORK       ≤ 10k     ≤ 100
# 34              Alliance for Justice Action Campaign       ≤ 10k     ≤ 100
# 35                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 36                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 37  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 38                                  Suraj Patel 2022    10k-100k    100-1k
# 39                                   Lost Debate Inc       ≤ 10k    100-1k
# 40                                  Suraj Patel 2022    10k-100k    100-1k
# 41                                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 42                  MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 43                               ZELDIN FOR NEW YORK       ≤ 10k     ≤ 100
# 44                                   Lost Debate Inc       ≤ 10k     ≤ 100
# 45  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 46                                        Ned for CT     100k-1M    1k-50k
# 47      Republican State Leadership Committee - RSLC     100k-1M    1k-50k
# 48                                  SAHAK NALBANDYAN    10k-100k    100-1k
#
#                                            youtube_id  video_available  \
# 0                                         3tbi7bkvn9g             True
# 1                                         2Xn9wTIo-AA             True
# 2                                         UfuAU9dJmvA             True
# 3   youtube_id not available: this ad violated goo...            False
# 4                                         UcQHDSvtl90             True
# 5                                         jG6NGdLUHeM             True
# 6                                         GwiWAmH9Pd4             True
# 7                                         y68knSZLsdA             True
# 8                                         zyu4BUYbf4U             True
# 9                                         GsX_SUh-p7U             True
# 10                                        sBJnbpNXRRQ             True
# 11                                        nfgAYr_4MQs             True
# 12                                        pzLwTOpn9mc             True
# 13                                        PkHASyqBkRQ             True
# 14  youtube_id not available: cannot load the vide...            False
# 15                                        NgXyszPPnAE             True
# 16                                        AbY0VFLLfJs             True
# 17                                        TmkR9l5dWb0             True
# 18                                        XyDh1Q28WdU             True
# 19                                        6UURc_GKLhI             True
# 20                                        ZcYpjMNoQy4             True
# 21                                        bkQUfwMNUnc             True
# 22                                        ZxThpvGEpHo             True
# 23                                        EU6g-LFozt4             True
# 24                                        xTcVCKibNWY             True
# 25                                        E7JaPh5_nWg             True
# 26                                        Nlc8TGeusVo             True
# 27                                        l4sKS82_6QQ             True
# 28                                        9o-wbQOyMa4             True
# 29                                        Hczz2OL2oZE             True
# 30                                        lLfw41piWBg             True
# 31                                        y-trUmtEIsM             True
# 32                                        vfQVWp6Bw8A             True
# 33                                        lHPwIYWLp_g             True
# 34                                        m0ddpYiUzjY             True
# 35                                        EPrj6MEu_EU             True
# 36                                        aITbTMQLzVY             True
# 37                                        rRZSbeIqunw             True
# 38                                        ij7I7JMMOW4             True
# 39                                        GRL_waoduNA             True
# 40                                        2TXGM_-ahdU             True
# 41                                        8Fj9aEnCZq0             True
# 42                                        n8p9bcRbLxs             True
# 43                                        QPqm3k9WMAU             True
# 44                                        ofYDKb8aGjY             True
# 45                                        AT9RMxt8zIo             True
# 46                                        KcFV6qz7dJQ             True
# 47                                        TLFDi2FTo-c             True
# 48                                        fOCUqnSVIFY             True
#
#                                                  text
# 0    these people actually hate america there's no...
# 1    what is the state of washington dc your natio...
# 2    [Music] welcome to the lost debate a show for...
# 3   \nCould not retrieve a transcript for the vide...
# 4    [Music] my dad started at a steel plant and t...
# 5    general michael flynn was unmasked at least 4...
# 6    i'm fighting to help families keep up with ri...
# 7    oh there we go hey there we go sam oh yeah he...
# 8    38 states have officially approved the bounda...
# 9    with all of the news about the pandemic and t...
# 10   [Music] welcome to the lost debate a show for...
# 11   inflation is at its highest level in 40 years...
# 12   morgan president biden opened the leaders sum...
# 13   as i speak this is the last day of january uh...
# 14  \nCould not retrieve a transcript for the vide...
# 15   [Music] welcome to the lost debate a show for...
# 16   we have breaking news now it is official gove...
# 17   this is johnstown the town i grew up in my da...
# 18   change doesn't come easy but it will come if ...
# 19          my name is carolyn maloney i work for you
# 20   from ending surprise medical billing to makin...
# 21   [Music] president biden just nominated one of...
# 22   i will fight for a green new deal to hold big...
# 23   middle-class americans are struggling to find...
# 24   joe morelli fights for our families that's wh...
# 25   [Music] i'm highly suspicious of those in gov...
# 26   urgent the u.s is now permitting seniors with...
# 27   i've been fighting for progressive values my ...
# 28   i'm cutting taxes for middle class families b...
# 29   foreign please rise for our national anthem o...
# 30   my parents taught me not to waste time when t...
# 31   [Music] welcome to the lost debate a show for...
# 32   [Music] welcome to the lost debate on convent...
# 33   Some say New York should just turn out the li...
# 34   civil rights attorney dale ho has dedicated h...
# 35   [Music] welcome to the lost debate a show for...
# 36   we've all heard the old saying if you add 7 m...
# 37   it's not about what's happening in congress i...
# 38   zurich patel went from bussing tables to serv...
# 39   [Music] welcome to the lost debate a show for...
# 40   my story it's the story of new york it's of a...
# 41   attention homeowners if you have a meter like...
# 42  \nCould not retrieve a transcript for the vide...
# 43   Are we ready to fire Kathy Hochul? Do we want...
# 44  \nCould not retrieve a transcript for the vide...
# 45   joe morelli knows we can't just sit back when...
# 46   while washington bickers here in connecticut ...
# 47   attention biden voters if you voted for biden...
# 48   if you've thought about going solar i want yo...

# %%
remove_advertiser = ['Lost Debate Inc','TURNING POINT USA, NFP']
ny_captions = ny_captions[-ny_captions['advertiser_name'].isin(remove_advertiser)]
ny_captions
# Out:
#                                                ad_url  \
# 3   https://transparencyreport.google.com/politica...
# 4   https://transparencyreport.google.com/politica...
# 5   https://transparencyreport.google.com/politica...
# 6   https://transparencyreport.google.com/politica...
# 12  https://transparencyreport.google.com/politica...
# 13  https://transparencyreport.google.com/politica...
# 16  https://transparencyreport.google.com/politica...
# 17  https://transparencyreport.google.com/politica...
# 18  https://transparencyreport.google.com/politica...
# 19  https://transparencyreport.google.com/politica...
# 20  https://transparencyreport.google.com/politica...
# 21  https://transparencyreport.google.com/politica...
# 22  https://transparencyreport.google.com/politica...
# 23  https://transparencyreport.google.com/politica...
# 24  https://transparencyreport.google.com/politica...
# 25  https://transparencyreport.google.com/politica...
# 26  https://transparencyreport.google.com/politica...
# 27  https://transparencyreport.google.com/politica...
# 28  https://transparencyreport.google.com/politica...
# 30  https://transparencyreport.google.com/politica...
# 33  https://transparencyreport.google.com/politica...
# 34  https://transparencyreport.google.com/politica...
# 37  https://transparencyreport.google.com/politica...
# 38  https://transparencyreport.google.com/politica...
# 40  https://transparencyreport.google.com/politica...
# 41  https://transparencyreport.google.com/politica...
# 42  https://transparencyreport.google.com/politica...
# 43  https://transparencyreport.google.com/politica...
# 45  https://transparencyreport.google.com/politica...
# 46  https://transparencyreport.google.com/politica...
# 47  https://transparencyreport.google.com/politica...
# 48  https://transparencyreport.google.com/politica...
#
#                                      advertiser_name impressions spend_usd  \
# 3                                ZELDIN FOR NEW YORK       ≤ 10k     ≤ 100
# 4                           Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 5                   MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 6                           Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 12                                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 13                                   Sabbath Lafleur       ≤ 10k     ≤ 100
# 16                                        Ned for CT      1M-10M    1k-50k
# 17                          TAXPAYERS FOR WILSON INC     100k-1M    1k-50k
# 18                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 19                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 20  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 21              Alliance for Justice Action Campaign    10k-100k    1k-50k
# 22                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 23                           AMERICAN ACTION NETWORK     100k-1M    1k-50k
# 24  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 25                               ZELDIN FOR NEW YORK     100k-1M    1k-50k
# 26                                          1111 LLC     100k-1M    1k-50k
# 27                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 28                          Friends for Kathy Hochul    10k-100k    100-1k
# 30                          Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 33                               ZELDIN FOR NEW YORK       ≤ 10k     ≤ 100
# 34              Alliance for Justice Action Campaign       ≤ 10k     ≤ 100
# 37  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 38                                  Suraj Patel 2022    10k-100k    100-1k
# 40                                  Suraj Patel 2022    10k-100k    100-1k
# 41                                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 42                  MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 43                               ZELDIN FOR NEW YORK       ≤ 10k     ≤ 100
# 45  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 46                                        Ned for CT     100k-1M    1k-50k
# 47      Republican State Leadership Committee - RSLC     100k-1M    1k-50k
# 48                                  SAHAK NALBANDYAN    10k-100k    100-1k
#
#                                            youtube_id  video_available  \
# 3   youtube_id not available: this ad violated goo...            False
# 4                                         UcQHDSvtl90             True
# 5                                         jG6NGdLUHeM             True
# 6                                         GwiWAmH9Pd4             True
# 12                                        pzLwTOpn9mc             True
# 13                                        PkHASyqBkRQ             True
# 16                                        AbY0VFLLfJs             True
# 17                                        TmkR9l5dWb0             True
# 18                                        XyDh1Q28WdU             True
# 19                                        6UURc_GKLhI             True
# 20                                        ZcYpjMNoQy4             True
# 21                                        bkQUfwMNUnc             True
# 22                                        ZxThpvGEpHo             True
# 23                                        EU6g-LFozt4             True
# 24                                        xTcVCKibNWY             True
# 25                                        E7JaPh5_nWg             True
# 26                                        Nlc8TGeusVo             True
# 27                                        l4sKS82_6QQ             True
# 28                                        9o-wbQOyMa4             True
# 30                                        lLfw41piWBg             True
# 33                                        lHPwIYWLp_g             True
# 34                                        m0ddpYiUzjY             True
# 37                                        rRZSbeIqunw             True
# 38                                        ij7I7JMMOW4             True
# 40                                        2TXGM_-ahdU             True
# 41                                        8Fj9aEnCZq0             True
# 42                                        n8p9bcRbLxs             True
# 43                                        QPqm3k9WMAU             True
# 45                                        AT9RMxt8zIo             True
# 46                                        KcFV6qz7dJQ             True
# 47                                        TLFDi2FTo-c             True
# 48                                        fOCUqnSVIFY             True
#
#                                                  text
# 3   \nCould not retrieve a transcript for the vide...
# 4    [Music] my dad started at a steel plant and t...
# 5    general michael flynn was unmasked at least 4...
# 6    i'm fighting to help families keep up with ri...
# 12   morgan president biden opened the leaders sum...
# 13   as i speak this is the last day of january uh...
# 16   we have breaking news now it is official gove...
# 17   this is johnstown the town i grew up in my da...
# 18   change doesn't come easy but it will come if ...
# 19          my name is carolyn maloney i work for you
# 20   from ending surprise medical billing to makin...
# 21   [Music] president biden just nominated one of...
# 22   i will fight for a green new deal to hold big...
# 23   middle-class americans are struggling to find...
# 24   joe morelli fights for our families that's wh...
# 25   [Music] i'm highly suspicious of those in gov...
# 26   urgent the u.s is now permitting seniors with...
# 27   i've been fighting for progressive values my ...
# 28   i'm cutting taxes for middle class families b...
# 30   my parents taught me not to waste time when t...
# 33   Some say New York should just turn out the li...
# 34   civil rights attorney dale ho has dedicated h...
# 37   it's not about what's happening in congress i...
# 38   zurich patel went from bussing tables to serv...
# 40   my story it's the story of new york it's of a...
# 41   attention homeowners if you have a meter like...
# 42  \nCould not retrieve a transcript for the vide...
# 43   Are we ready to fire Kathy Hochul? Do we want...
# 45   joe morelli knows we can't just sit back when...
# 46   while washington bickers here in connecticut ...
# 47   attention biden voters if you voted for biden...
# 48   if you've thought about going solar i want yo...

# %%
# remove unavialable videos
ny_captions_available = ny_captions[ny_captions['video_available'] == True]
ny_captions_clean = clean_text(ny_captions_available)
ny_captions_clean
# Out:
# /var/folders/fh/9s8xqf557hxb9jfsjxs123f80000gq/T/ipykernel_15040/197128158.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['text'] = df_text['text'].astype(str).apply(lambda x: filter_text(x))
# /var/folders/fh/9s8xqf557hxb9jfsjxs123f80000gq/T/ipykernel_15040/197128158.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['text'] = df_text['text'].replace('/u0026', ' ')
# /var/folders/fh/9s8xqf557hxb9jfsjxs123f80000gq/T/ipykernel_15040/197128158.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text.drop_duplicates(subset = 'text',keep = 'first', inplace = True)
#                                                ad_url  \
# 0   https://transparencyreport.google.com/politica...
# 1   https://transparencyreport.google.com/politica...
# 2   https://transparencyreport.google.com/politica...
# 3   https://transparencyreport.google.com/politica...
# 4   https://transparencyreport.google.com/politica...
# 5   https://transparencyreport.google.com/politica...
# 6   https://transparencyreport.google.com/politica...
# 7   https://transparencyreport.google.com/politica...
# 8   https://transparencyreport.google.com/politica...
# 9   https://transparencyreport.google.com/politica...
# 10  https://transparencyreport.google.com/politica...
# 11  https://transparencyreport.google.com/politica...
# 12  https://transparencyreport.google.com/politica...
# 13  https://transparencyreport.google.com/politica...
# 14  https://transparencyreport.google.com/politica...
# 15  https://transparencyreport.google.com/politica...
# 16  https://transparencyreport.google.com/politica...
# 17  https://transparencyreport.google.com/politica...
# 18  https://transparencyreport.google.com/politica...
# 19  https://transparencyreport.google.com/politica...
# 20  https://transparencyreport.google.com/politica...
# 21  https://transparencyreport.google.com/politica...
# 22  https://transparencyreport.google.com/politica...
# 23  https://transparencyreport.google.com/politica...
# 24  https://transparencyreport.google.com/politica...
# 25  https://transparencyreport.google.com/politica...
# 26  https://transparencyreport.google.com/politica...
# 27  https://transparencyreport.google.com/politica...
# 28  https://transparencyreport.google.com/politica...
# 29  https://transparencyreport.google.com/politica...
# 30  https://transparencyreport.google.com/politica...
#
#                                      advertiser_name impressions spend_usd  \
# 0                           Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 1                   MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 2                           Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 3                                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 4                                    Sabbath Lafleur       ≤ 10k     ≤ 100
# 5                                         Ned for CT      1M-10M    1k-50k
# 6                           TAXPAYERS FOR WILSON INC     100k-1M    1k-50k
# 7                               MALONEY FOR CONGRESS     100k-1M    1k-50k
# 8                               MALONEY FOR CONGRESS     100k-1M    1k-50k
# 9   REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 10              Alliance for Justice Action Campaign    10k-100k    1k-50k
# 11                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 12                           AMERICAN ACTION NETWORK     100k-1M    1k-50k
# 13  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 14                               ZELDIN FOR NEW YORK     100k-1M    1k-50k
# 15                                          1111 LLC     100k-1M    1k-50k
# 16                              MALONEY FOR CONGRESS     100k-1M    1k-50k
# 17                          Friends for Kathy Hochul    10k-100k    100-1k
# 18                          Friends for Kathy Hochul       ≤ 10k     ≤ 100
# 19                               ZELDIN FOR NEW YORK       ≤ 10k     ≤ 100
# 20              Alliance for Justice Action Campaign       ≤ 10k     ≤ 100
# 21  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 22                                  Suraj Patel 2022    10k-100k    100-1k
# 23                                  Suraj Patel 2022    10k-100k    100-1k
# 24                                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 25                  MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 26                               ZELDIN FOR NEW YORK       ≤ 10k     ≤ 100
# 27  REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES     100k-1M    1k-50k
# 28                                        Ned for CT     100k-1M    1k-50k
# 29      Republican State Leadership Committee - RSLC     100k-1M    1k-50k
# 30                                  SAHAK NALBANDYAN    10k-100k    100-1k
#
#      youtube_id  video_available  \
# 0   UcQHDSvtl90             True
# 1   jG6NGdLUHeM             True
# 2   GwiWAmH9Pd4             True
# 3   pzLwTOpn9mc             True
# 4   PkHASyqBkRQ             True
# 5   AbY0VFLLfJs             True
# 6   TmkR9l5dWb0             True
# 7   XyDh1Q28WdU             True
# 8   6UURc_GKLhI             True
# 9   ZcYpjMNoQy4             True
# 10  bkQUfwMNUnc             True
# 11  ZxThpvGEpHo             True
# 12  EU6g-LFozt4             True
# 13  xTcVCKibNWY             True
# 14  E7JaPh5_nWg             True
# 15  Nlc8TGeusVo             True
# 16  l4sKS82_6QQ             True
# 17  9o-wbQOyMa4             True
# 18  lLfw41piWBg             True
# 19  lHPwIYWLp_g             True
# 20  m0ddpYiUzjY             True
# 21  rRZSbeIqunw             True
# 22  ij7I7JMMOW4             True
# 23  2TXGM_-ahdU             True
# 24  8Fj9aEnCZq0             True
# 25  n8p9bcRbLxs             True
# 26  QPqm3k9WMAU             True
# 27  AT9RMxt8zIo             True
# 28  KcFV6qz7dJQ             True
# 29  TLFDi2FTo-c             True
# 30  fOCUqnSVIFY             True
#
#                                                  text
# 0   music my dad started at a steel plant and taug...
# 1   general michael flynn was unmasked at least 48...
# 2   i m fighting to help families keep up with ris...
# 3   morgan president biden opened the leaders summ...
# 4   as i speak this is the last day of january uh ...
# 5   we have breaking news now it is official gover...
# 6   this is johnstown the town i grew up in my dad...
# 7   change doesn t come easy but it will come if y...
# 8           my name is carolyn maloney i work for you
# 9   from ending surprise medical billing to making...
# 10  music president biden just nominated one of th...
# 11  i will fight for a green new deal to hold big ...
# 12  middle class americans are struggling to find ...
# 13  joe morelli fights for our families that s why...
# 14  music i m highly suspicious of those in govern...
# 15  urgent the u s is now permitting seniors with ...
# 16  i ve been fighting for progressive values my e...
# 17  i m cutting taxes for middle class families be...
# 18  my parents taught me not to waste time when th...
# 19  some say new york should just turn out the lig...
# 20  civil rights attorney dale ho has dedicated hi...
# 21  it s not about what s happening in congress it...
# 22  zurich patel went from bussing tables to servi...
# 23  my story it s the story of new york it s of an...
# 24  attention homeowners if you have a meter like ...
# 25  could not retrieve a transcript for the video ...
# 26  are we ready to fire kathy hochul do we want t...
# 27  joe morelli knows we can t just sit back when ...
# 28  while washington bickers here in connecticut i...
# 29  attention biden voters if you voted for biden ...
# 30  if you ve thought about going solar i want you...

# %%
ny_captions_tagged = get_word_lable(ny_captions_clean,'lexicon.json')
ny_captions_tagged
ny_captions_tagged.to_csv('ny_captions_tagged.csv')
# Out:
# /var/folders/fh/9s8xqf557hxb9jfsjxs123f80000gq/T/ipykernel_15040/3945606449.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['words'] = df_text['text'].astype(str).apply(lambda x: find_words(x,dic))
# /var/folders/fh/9s8xqf557hxb9jfsjxs123f80000gq/T/ipykernel_15040/3945606449.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['m_label'] = df_text['words'].apply(lambda x: find_topic(x,dic))
# /var/folders/fh/9s8xqf557hxb9jfsjxs123f80000gq/T/ipykernel_15040/3945606449.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['m_label'] = df_text['m_label'].apply(lambda x: 'no topic' if x=='' else x)

# %%
count_topic(ny_captions_tagged)
# Out:
#            single_topic  counts
# 0              economic      11
# 1            governance      10
# 2       social programs       8
# 3              no topic       6
# 4                safety       6
# 5           environment       5
# 6             education       4
# 7                health       4
# 8            polarizing       4
# 9        foreign policy       3
# 10  social and cultural       3
# 11        establishment       1

# %%
count_word(ny_captions_tagged)
# Out:
#           single_word  counts
# 0               taxes       6
# 1            no words       6
# 2                 law       5
# 3                 tax       5
# 4             liberal       3
# ..                ...     ...
# 83      michael brown       1
# 84         corruption       1
# 85           new deal       1
# 86  committing crimes       1
# 87           officers       1
#
# [88 rows x 2 columns]

# %%
ny_captions_tagged['advertiser_name'].value_counts()
# Out:
# Friends for Kathy Hochul                            4
# MALONEY FOR CONGRESS                                4
# REP. JOE MORELLE - U.S. HOUSE OF REPRESENTATIVES    4
# SAHAK NALBANDYAN                                    3
# ZELDIN FOR NEW YORK                                 3
# MARKETFUEL SUBSCRIPTION SERVICES                    2
# Ned for CT                                          2
# Alliance for Justice Action Campaign                2
# Suraj Patel 2022                                    2
# Sabbath Lafleur                                     1
# TAXPAYERS FOR WILSON INC                            1
# AMERICAN ACTION NETWORK                             1
# 1111 LLC                                            1
# Republican State Leadership Committee - RSLC        1
# Name: advertiser_name, dtype: int64

# %% [markdown]
# # CT

# %%
ct_video = get_youtube_id('GoogleAds/CT.csv')
ct_video_clean = check_video(ct_video)
ct_captions = get_captions(ct_video_clean)
ct_captions
# Out:
#                                                ad_url  \
# 0   https://transparencyreport.google.com/politica...
# 1   https://transparencyreport.google.com/politica...
# 2   https://transparencyreport.google.com/politica...
# 3   https://transparencyreport.google.com/politica...
# 4   https://transparencyreport.google.com/politica...
# 5   https://transparencyreport.google.com/politica...
# 6   https://transparencyreport.google.com/politica...
# 7   https://transparencyreport.google.com/politica...
# 8   https://transparencyreport.google.com/politica...
# 9   https://transparencyreport.google.com/politica...
# 10  https://transparencyreport.google.com/politica...
# 11  https://transparencyreport.google.com/politica...
# 12  https://transparencyreport.google.com/politica...
# 13  https://transparencyreport.google.com/politica...
# 14  https://transparencyreport.google.com/politica...
# 15  https://transparencyreport.google.com/politica...
# 16  https://transparencyreport.google.com/politica...
# 17  https://transparencyreport.google.com/politica...
# 18  https://transparencyreport.google.com/politica...
# 19  https://transparencyreport.google.com/politica...
# 20  https://transparencyreport.google.com/politica...
# 21  https://transparencyreport.google.com/politica...
# 22  https://transparencyreport.google.com/politica...
# 23  https://transparencyreport.google.com/politica...
# 24  https://transparencyreport.google.com/politica...
# 25  https://transparencyreport.google.com/politica...
# 26  https://transparencyreport.google.com/politica...
# 27  https://transparencyreport.google.com/politica...
# 28  https://transparencyreport.google.com/politica...
# 29  https://transparencyreport.google.com/politica...
# 30  https://transparencyreport.google.com/politica...
# 31  https://transparencyreport.google.com/politica...
#
#                      advertiser_name impressions spend_usd  \
# 0             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 1             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 2             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 3                               NRSC       ≤ 10k     ≤ 100
# 4                    Lost Debate Inc       ≤ 10k     ≤ 100
# 5                    Lost Debate Inc       ≤ 10k     ≤ 100
# 6                    Lost Debate Inc       ≤ 10k     ≤ 100
# 7             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 8             TURNING POINT USA, NFP       ≤ 10k     ≤ 100
# 9                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 10                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 11                   Lost Debate Inc       ≤ 10k     ≤ 100
# 12                   Lost Debate Inc       ≤ 10k     ≤ 100
# 13                   Lost Debate Inc       ≤ 10k     ≤ 100
# 14                   Lost Debate Inc       ≤ 10k     ≤ 100
# 15                   Lost Debate Inc       ≤ 10k     ≤ 100
# 16                   Lost Debate Inc       ≤ 10k     ≤ 100
# 17                   Lost Debate Inc       ≤ 10k     ≤ 100
# 18                   Lost Debate Inc       ≤ 10k    100-1k
# 19                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100
# 20  MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 21                   Lost Debate Inc       ≤ 10k     ≤ 100
# 22                 CT Truth PAC Inc.      1M-10M    1k-50k
# 23              BOB FOR GOVERNOR INC     100k-1M    1k-50k
# 24              BOB FOR GOVERNOR INC     100k-1M    1k-50k
# 25     MORE PERFECT UNION FOUNDATION    10k-100k     ≤ 100
# 26  MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100
# 27              BOB FOR GOVERNOR INC       ≤ 10k     ≤ 100
# 28                   Lost Debate Inc       ≤ 10k     ≤ 100
# 29                 CT Truth PAC Inc.      1M-10M    1k-50k
# 30                 CT Truth PAC Inc.     100k-1M    1k-50k
# 31                          1111 LLC     100k-1M    1k-50k
#
#                                            youtube_id  video_available  \
# 0   youtube_id not available: this ad violated goo...            False
# 1                                         Hczz2OL2oZE             True
# 2                                         3tbi7bkvn9g             True
# 3                                         5beJUEo67Q8             True
# 4                                         sBJnbpNXRRQ             True
# 5                                         UfuAU9dJmvA             True
# 6                                         y-trUmtEIsM             True
# 7                                         y68knSZLsdA             True
# 8                                         2Xn9wTIo-AA             True
# 9                                         pzLwTOpn9mc             True
# 10                                        fOCUqnSVIFY             True
# 11                                        vfQVWp6Bw8A             True
# 12                                        zyu4BUYbf4U             True
# 13                                        NgXyszPPnAE             True
# 14                                        GsX_SUh-p7U             True
# 15  youtube_id not available: cannot load the vide...            False
# 16                                        EPrj6MEu_EU             True
# 17                                        aITbTMQLzVY             True
# 18                                        GRL_waoduNA             True
# 19                                        8Fj9aEnCZq0             True
# 20                                        n8p9bcRbLxs             True
# 21                                        ofYDKb8aGjY             True
# 22                                        quOQFzWj-NI             True
# 23                                        wKU7AnYiHZo             True
# 24                                        8zBTxobxS3E             True
# 25                                        fiLusO7JopQ             True
# 26                                        jG6NGdLUHeM             True
# 27                                        8rCBRt4koW8             True
# 28                                        nfgAYr_4MQs             True
# 29                                        igI2gorHlbk             True
# 30                                        jKYt8-z_MGg             True
# 31                                        Nlc8TGeusVo             True
#
#                                                  text
# 0   \nCould not retrieve a transcript for the vide...
# 1    foreign please rise for our national anthem o...
# 2    these people actually hate america there's no...
# 3   \nCould not retrieve a transcript for the vide...
# 4    [Music] welcome to the lost debate a show for...
# 5    [Music] welcome to the lost debate a show for...
# 6    [Music] welcome to the lost debate a show for...
# 7    oh there we go hey there we go sam oh yeah he...
# 8    what is the state of washington dc your natio...
# 9    morgan president biden opened the leaders sum...
# 10   if you've thought about going solar i want yo...
# 11   [Music] welcome to the lost debate on convent...
# 12   38 states have officially approved the bounda...
# 13   [Music] welcome to the lost debate a show for...
# 14   with all of the news about the pandemic and t...
# 15  \nCould not retrieve a transcript for the vide...
# 16   [Music] welcome to the lost debate a show for...
# 17   we've all heard the old saying if you add 7 m...
# 18   [Music] welcome to the lost debate a show for...
# 19   attention homeowners if you have a meter like...
# 20  \nCould not retrieve a transcript for the vide...
# 21  \nCould not retrieve a transcript for the vide...
# 22   the fbi is investigating how the lamont admin...
# 23   bob stefanowski an agenda that puts transpare...
# 24   bob stefanowski he's a fantastic listener and...
# 25   what you're seeing around the country is alre...
# 26   general michael flynn was unmasked at least 4...
# 27   good morning this is bob stefanowski his gran...
# 28   inflation is at its highest level in 40 years...
# 29   the fbi is investigating how the lamont admin...
# 30   i get to give a speech now costa's got to del...
# 31   urgent the u.s is now permitting seniors with...

# %%
remove_advertiser = ['Lost Debate Inc','TURNING POINT USA, NFP']
ct_captions = ct_captions[-ct_captions['advertiser_name'].isin(remove_advertiser)]
ct_captions
# Out:
#                                                ad_url  \
# 3   https://transparencyreport.google.com/politica...
# 9   https://transparencyreport.google.com/politica...
# 10  https://transparencyreport.google.com/politica...
# 19  https://transparencyreport.google.com/politica...
# 20  https://transparencyreport.google.com/politica...
# 22  https://transparencyreport.google.com/politica...
# 23  https://transparencyreport.google.com/politica...
# 24  https://transparencyreport.google.com/politica...
# 25  https://transparencyreport.google.com/politica...
# 26  https://transparencyreport.google.com/politica...
# 27  https://transparencyreport.google.com/politica...
# 29  https://transparencyreport.google.com/politica...
# 30  https://transparencyreport.google.com/politica...
# 31  https://transparencyreport.google.com/politica...
#
#                      advertiser_name impressions spend_usd   youtube_id  \
# 3                               NRSC       ≤ 10k     ≤ 100  5beJUEo67Q8
# 9                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100  pzLwTOpn9mc
# 10                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100  fOCUqnSVIFY
# 19                  SAHAK NALBANDYAN       ≤ 10k     ≤ 100  8Fj9aEnCZq0
# 20  MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100  n8p9bcRbLxs
# 22                 CT Truth PAC Inc.      1M-10M    1k-50k  quOQFzWj-NI
# 23              BOB FOR GOVERNOR INC     100k-1M    1k-50k  wKU7AnYiHZo
# 24              BOB FOR GOVERNOR INC     100k-1M    1k-50k  8zBTxobxS3E
# 25     MORE PERFECT UNION FOUNDATION    10k-100k     ≤ 100  fiLusO7JopQ
# 26  MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100  jG6NGdLUHeM
# 27              BOB FOR GOVERNOR INC       ≤ 10k     ≤ 100  8rCBRt4koW8
# 29                 CT Truth PAC Inc.      1M-10M    1k-50k  igI2gorHlbk
# 30                 CT Truth PAC Inc.     100k-1M    1k-50k  jKYt8-z_MGg
# 31                          1111 LLC     100k-1M    1k-50k  Nlc8TGeusVo
#
#     video_available                                               text
# 3              True  \nCould not retrieve a transcript for the vide...
# 9              True   morgan president biden opened the leaders sum...
# 10             True   if you've thought about going solar i want yo...
# 19             True   attention homeowners if you have a meter like...
# 20             True  \nCould not retrieve a transcript for the vide...
# 22             True   the fbi is investigating how the lamont admin...
# 23             True   bob stefanowski an agenda that puts transpare...
# 24             True   bob stefanowski he's a fantastic listener and...
# 25             True   what you're seeing around the country is alre...
# 26             True   general michael flynn was unmasked at least 4...
# 27             True   good morning this is bob stefanowski his gran...
# 29             True   the fbi is investigating how the lamont admin...
# 30             True   i get to give a speech now costa's got to del...
# 31             True   urgent the u.s is now permitting seniors with...

# %%
# remove unavialable videos
ct_captions_available = ct_captions[ct_captions['video_available'] == True]
ct_captions_clean = clean_text(ct_captions_available)
ct_captions_clean
# Out:
#                                                ad_url  \
# 0   https://transparencyreport.google.com/politica...
# 1   https://transparencyreport.google.com/politica...
# 2   https://transparencyreport.google.com/politica...
# 3   https://transparencyreport.google.com/politica...
# 4   https://transparencyreport.google.com/politica...
# 5   https://transparencyreport.google.com/politica...
# 6   https://transparencyreport.google.com/politica...
# 7   https://transparencyreport.google.com/politica...
# 8   https://transparencyreport.google.com/politica...
# 9   https://transparencyreport.google.com/politica...
# 10  https://transparencyreport.google.com/politica...
# 11  https://transparencyreport.google.com/politica...
# 12  https://transparencyreport.google.com/politica...
# 13  https://transparencyreport.google.com/politica...
#
#                      advertiser_name impressions spend_usd   youtube_id  \
# 0                               NRSC       ≤ 10k     ≤ 100  5beJUEo67Q8
# 1                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100  pzLwTOpn9mc
# 2                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100  fOCUqnSVIFY
# 3                   SAHAK NALBANDYAN       ≤ 10k     ≤ 100  8Fj9aEnCZq0
# 4   MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100  n8p9bcRbLxs
# 5                  CT Truth PAC Inc.      1M-10M    1k-50k  quOQFzWj-NI
# 6               BOB FOR GOVERNOR INC     100k-1M    1k-50k  wKU7AnYiHZo
# 7               BOB FOR GOVERNOR INC     100k-1M    1k-50k  8zBTxobxS3E
# 8      MORE PERFECT UNION FOUNDATION    10k-100k     ≤ 100  fiLusO7JopQ
# 9   MARKETFUEL SUBSCRIPTION SERVICES       ≤ 10k     ≤ 100  jG6NGdLUHeM
# 10              BOB FOR GOVERNOR INC       ≤ 10k     ≤ 100  8rCBRt4koW8
# 11                 CT Truth PAC Inc.      1M-10M    1k-50k  igI2gorHlbk
# 12                 CT Truth PAC Inc.     100k-1M    1k-50k  jKYt8-z_MGg
# 13                          1111 LLC     100k-1M    1k-50k  Nlc8TGeusVo
#
#     video_available                                               text
# 0              True  could not retrieve a transcript for the video ...
# 1              True  morgan president biden opened the leaders summ...
# 2              True  if you ve thought about going solar i want you...
# 3              True  attention homeowners if you have a meter like ...
# 4              True  could not retrieve a transcript for the video ...
# 5              True  the fbi is investigating how the lamont admini...
# 6              True  bob stefanowski an agenda that puts transparen...
# 7              True  bob stefanowski he s a fantastic listener and ...
# 8              True  what you re seeing around the country is alrea...
# 9              True  general michael flynn was unmasked at least 48...
# 10             True  good morning this is bob stefanowski his grand...
# 11             True  the fbi is investigating how the lamont admini...
# 12             True  i get to give a speech now costa s got to deli...
# 13             True  urgent the u s is now permitting seniors with ...

# %%
ct_captions_tagged = get_word_lable(ct_captions_clean,'lexicon.json')
ct_captions_tagged.to_csv('ct_captions_tagged.csv')

# %%
count_topic(ct_captions_tagged)
# Out:
#            single_topic  counts
# 0              no topic       5
# 1            governance       4
# 2              economic       3
# 3           environment       3
# 4        foreign policy       2
# 5                health       2
# 6            polarizing       2
# 7       social programs       2
# 8         establishment       1
# 9           immigration       1
# 10               safety       1
# 11  social and cultural       1

# %%
count_word(ct_captions_tagged)
# Out:
#             single_word  counts
# 0              no words       5
# 1                values       2
# 2                health       2
# 3            corruption       2
# 4              abortion       1
# 5             pollution       1
# 6                   law       1
# 7                  laws       1
# 8                   nsa       1
# 9         out of pocket       1
# 10      people of color       1
# 11              persian       1
# 12          power plant       1
# 13                khmer       1
# 14               racial       1
# 15         solar panels       1
# 16                  tax       1
# 17                taxes       1
# 18       transportation       1
# 19              turkish       1
# 20        voting rights       1
# 21              kurdish       1
# 22            interests       1
# 23         job creation       1
# 24            abortions       1
# 25                 barr       1
# 26                black       1
# 27               carbon       1
# 28              climate       1
# 29       discrimination       1
# 30             economic       1
# 31  economic imperative       1
# 32            emissions       1
# 33         energy costs       1
# 34             estonian       1
# 35    expanded medicaid       1
# 36              foreign       1
# 37       gerrymandering       1
# 38           greenhouse       1
# 39       greenhouse gas       1
# 40      health coverage       1
# 41           immigrants       1
# 42              workers       1

# %%
ct_captions_tagged['advertiser_name'].value_counts()
# Out:
# SAHAK NALBANDYAN                    3
# CT Truth PAC Inc.                   3
# BOB FOR GOVERNOR INC                3
# MARKETFUEL SUBSCRIPTION SERVICES    2
# NRSC                                1
# MORE PERFECT UNION FOUNDATION       1
# 1111 LLC                            1
# Name: advertiser_name, dtype: int64
